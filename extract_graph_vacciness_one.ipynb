# %% [markdown]
# # 1. Setup

# %%
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


from helpers.semantic_features_vacciness_one_library import *


input_documents_directory = Path(f"./documents")
MODEL_IN_USE ='gemini'
NAME_OF_SIMULATION = f"results_ZDROWOTNE_baseline_2_ONE_{MODEL_IN_USE}"

date = datetime.now().strftime("%Y-%m-%d")


GENERATE_NEW_DVA_ANALYSIS = True
BASE_LINE_TEST = True

if "_3_" in NAME_OF_SIMULATION:
    SAMPLES_COUNT = 3
    print(f"Samples count {SAMPLES_COUNT}")
elif "_5_" in NAME_OF_SIMULATION:
    SAMPLES_COUNT = 5
    print(f"Samples count {SAMPLES_COUNT}")
elif "_10_" in NAME_OF_SIMULATION:
    SAMPLES_COUNT = 10
    print(f"Samples count {SAMPLES_COUNT}")
else:
    print("No SAMPLE_COUNT")



semantic_features_sim = {
    key: value[:SAMPLES_COUNT]
    for key, value in semantic_features_gemini_sim.items()
}


semantic_features_dif = {
    key: value[:SAMPLES_COUNT]
    for key, value in semantic_features_gemini_dif.items()
}


if "_SIM_" in NAME_OF_SIMULATION or "_sim_" in NAME_OF_SIMULATION:
    SEMANTIC_FEATURES = semantic_features_sim
    print(f"Checking for SIM {len(semantic_features_sim)}")
elif "_DIF_" in NAME_OF_SIMULATION or "_dif_" in NAME_OF_SIMULATION:
    SEMANTIC_FEATURES = semantic_features_dif
    print(f"Checking for DIF {len(semantic_features_dif)}")
else:
    print(f"Incorrect name for simulation")

#DATASET
file_path = f"{input_documents_directory}/vacciness_dataset.json"

os.makedirs(NAME_OF_SIMULATION, exist_ok=True)
RESULTS_PATH_NAME = f"{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}_results.json"
print(RESULTS_PATH_NAME)

print("All SETUP UP!")
# Out:
# Model all-MiniLM-L-v2 does not exist locally
# No sentence-transformers model found with name sentence-transformers/all-MiniLM-L-v2. Creating a new one with mean pooling.
# Error occurred: sentence-transformers/all-MiniLM-L-v2 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Nieprawidłowy opis symulacji
# results_ZDROWOTNE_baseline_2_ONE_gemini/results_ZDROWOTNE_baseline_2_ONE_gemini_results.json
# Using SVM method!
# All SETUP UP!

# %% [markdown]
# ## Check if the semantic features are different

# %%
from difflib import SequenceMatcher

sim_dict = semantic_features_sim
dif_dict = semantic_features_dif

THRESHOLD = 1

def similarity(a, b):
    return SequenceMatcher(None, a.strip().lower(), b.strip().lower()).ratio()

print(f"PRÓG PODOBIEŃSTWA: {THRESHOLD}\n")
print("=" * 70)

total_matches = 0
total_pairs = 0

for category in sim_dict:
    sim_list = sim_dict[category]
    dif_list = dif_dict.get(category, [])

    matches = []
    for i, s in enumerate(sim_list):
        for j, d in enumerate(dif_list):
            score = similarity(s, d)
            if score >= THRESHOLD:
                matches.append((i, j, round(score * 100, 1), s, d))

    pairs = len(sim_list) * len(dif_list)
    total_pairs += pairs
    total_matches += len(matches)

    print(f"\n📂 {category}")
    print(f"   SIM: {len(sim_list)} | DIF: {len(dif_list)} | Par: {pairs} | Dopasowań: {len(matches)}")

    if matches:
        for i, j, score, full_sim, full_dif in matches:
            print(f"\n   ✅ SIM[{i}] ↔ DIF[{j}]  ({score}%)")
            print(f"   SIM: {full_sim}")
            print(f"   DIF: {full_dif}")
            print(f"   {'-' * 60}")
    else:
        print("   ❌ Brak duplikatów powyżej progu")

print("\n" + "=" * 70)
OGOLNE_POKRYCIE = total_matches
print(f"ŁĄCZNIE par: {total_pairs} | Duplikatów między SIM a DIF: {total_matches}")
print("=" * 70)
# Out:
# PRÓG PODOBIEŃSTWA: 1
#
# ======================================================================
#
# 📂 vaccine_stance_base
#    SIM: 1 | DIF: 1 | Par: 1 | Dopasowań: 0
#    ❌ Brak duplikatów powyżej progu
#
# 📂 vaccine_stance_opposite
#    SIM: 1 | DIF: 1 | Par: 1 | Dopasowań: 0
#    ❌ Brak duplikatów powyżej progu
#
# ======================================================================
# ŁĄCZNIE par: 2 | Duplikatów między SIM a DIF: 0
# ======================================================================

# %% [markdown]
# ## 0.1 Create semantic features

# %% [markdown]
# ## 1. Loading documents

# %%
from langchain.schema import Document
from helpers.utils import open_json_file

coronavirus_texts = open_json_file(file_path)

# Convert to LangChain Document format, selecting only anti-vaccine articles
pages_negative = [
    Document(
        page_content=item["text"],
        page_wo_stop_words = None,  # Text of the document
        metadata={
            "title": item["title"],
            "source": item["source"],
            "vaccine_stance_opposite": item["vaccine_stance_opposite"],
        }
    )
    for item in coronavirus_texts if item["vaccine_stance_opposite"] 
]

# Convert to LangChain Document format, selecting only anti-vaccine articles
pages_positive = [
    Document(
        page_content=item["text"],
        page_wo_stop_words = None,  # Text of the document
        metadata={
            "title": item["title"],
            "source": item["source"],
            "vaccine_stance_opposite": item["vaccine_stance_opposite"],
        }
    )
    for item in coronavirus_texts if not item["vaccine_stance_opposite"] 
]


# Convert to LangChain Document format, selecting only anti-vaccine articles
pages_all = [
    Document(
        page_content=item["text"],
        page_wo_stop_words = None,  # Text of the document
        metadata={
            "title": item["title"],
            "source": item["source"],
            "vaccine_stance_opposite": item["vaccine_stance_opposite"],
        }
    )
    for item in coronavirus_texts
]

#print(len(pages))
# Output transformed data
all_conent_from_pages = []
for doc in pages_all:
    # print(doc.page_content)
    # print()
    all_conent_from_pages.append(doc.page_content)
one_string_for_all_content  = "] [".join(all_conent_from_pages)

print(len(pages_negative))
print(len(pages_positive))
print(len(pages_all))

# %% [markdown]
# # 0.1 Create semantic features

# %%
from helpers.semantic_multi_agent_definitions import *
from helpers.all_keys import *
# ================================================================
# KONFIGURACJA - ZDEFINIUJ SWOJE PARAMETRY TUTAJ
# ================================================================

# Klucze API - zastąp swoimi kluczami
API_KEYS = {
    "claude":  f"{API_KEY_ANTROPIC}",
    "gemini": f"{API_KEY_GEMINI}",    
    "openai":  f"{API_KEY_OPENAI}"
}

# Główna konfiguracja
CONFIG_CLAUDE = {
    "provider": "claude",              # Domyślny provider: claude, gemini, openai
    "model": "claude-sonnet-4-6",     # Konkretny model (opcjonalne)
    #"model": "claude-sonnet-4-20250514",
    "context_len": int(len(pages_all)*1),                # Liczba kluczowych fragmentów
    "max_tokens": 10000,              # Maksymalna liczba tokenów
    "temperature": 0.0,               # Temperatura generacji (0.0-1.0)
    "output_file": "def_political_SONNET_4p6",    # Plik wyjściowy
    "save_results": True,
}

CONFIG_OPENAI = {
    "provider": "openai",              # Domyślny provider: claude, gemini, openai
    "model": "gpt-5.2",     # Konkretny model (opcjonalne)
    "context_len": int(len(pages_all)*1),                # Liczba kluczowych fragm entów
    "temperature": 0.0, 
     "max_completion_tokens": 10000,             # Temperatura generacji (0.0-1.0)
    "output_file": "results_political_GPT_5p2",    # Plik wyjściowy
    "save_results": True,
}


CONFIG_GEIMINI = {
    "provider": "gemini",              # Domyślny provider: claude, gemini, openai
    "model": "gemini-3.1-pro",     # Konkretny model (opcjonalne)
    "context_len": int(len(pages_all)*1),                # Liczba kluczowych fragmentów
    "max_tokens": 10000,              # Maksymalna liczba tokenów
    "temperature": 0.0,               # Temperatura generacji (0.0-1.0)
    "output_file": "results_politics_GEMINI1.5",    # Plik wyjściowy
    "save_results": True,
}

CONFIG = CONFIG_OPENAI
def run_single_provider_analysis():
    """Uruchamia analizę z jednym providerem"""
    
    print("="*60)
    print("ANALIZA SEMANTYCZNA - JEDEN PROVIDER")
    print("="*60)
    
    # Pobierz konfigurację
    provider = CONFIG["provider"]
    print(provider)
    api_key = API_KEYS.get(provider)

    
    if not api_key:
        print(f"Błąd: Brak klucza API dla providera {provider}")
        print("Zaktualizuj API_KEYS w konfiguracji")
        return None
    
    # Pobierz tekst
    text = one_string_for_all_content
    
    print(f"Provider: {provider}")
    print(f"Model: {CONFIG.get('model', 'domyślny')}")
    print(f"Długość tekstu: {len(text)} znaków")
    print(f"Context length: {CONFIG_CLAUDE['context_len']}")
    print("-" * 40)
    

    IS_DEFINED_SEMANTIC_QUIALITIES = True
    if IS_DEFINED_SEMANTIC_QUIALITIES == True:
        DEFINED_SEMANTIC_QUALITIES = "government_intervention"
        #DEFINED_SEMANTIC_QUALITIES = "government_role, social_policy, economic_policy"
    else:
        DEFINED_SEMANTIC_QUALITIES = None

    print("---> Defined semantic quialities: ", DEFINED_SEMANTIC_QUALITIES)

    # Uruchom analizę
    results = extract_semantic_concepts_with_agents(
        text=text,
        api_key=api_key,
        provider=provider,
        model=CONFIG.get("model"),
        context_len=CONFIG["context_len"],
        max_tokens=CONFIG["max_completion_tokens"],
        temperature=CONFIG["temperature"],
        defined_semantic_domains=DEFINED_SEMANTIC_QUALITIES
    )
    
    # Zapisz wyniki
    if CONFIG["save_results"]:
        save_semantic_features(results, CONFIG["output_file"])
        print(f"\nWyniki zapisano do: {CONFIG['output_file']}")
    return results

GENERATE_NEW_SEMANTIC_FEAUTURE = False

if GENERATE_NEW_SEMANTIC_FEAUTURE:
    for i in range(3):
        print("-" * 10)
        print("Iteracja: " , i)
        print("-" * 10)
        run_single_provider_analysis()

# %% [markdown]
# #  0.2 Selecting DPs before simulation

# %%
import numpy as np
from numpy.linalg import norm
from scipy.stats import spearmanr
from helpers.polarization_embedings import *


def encode_texts_with_gemini(texts):
    embeddings = []
    for text in texts:
        emb = generate_embedding_openai(text=text)
        embeddings.append(emb)
    return np.vstack(embeddings)


def spearman_similarity(vec1, vec2):
    correlation, _ = spearmanr(vec1, vec2)
    return correlation


def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    similarity = dot_product / (norm(vec1) * norm(vec2) + 1e-10)
    return similarity



def build_similarity_matrix(pos_emb, neg_emb):
    """Buduje pełną macierz korelacji Spearmana między wszystkimi parami."""
    n_pos = len(pos_emb)
    n_neg = len(neg_emb)
    return np.array([
        [spearmanr(pos_emb[i], neg_emb[j]).statistic for j in range(n_neg)]
        for i in range(n_pos)
    ])



def select_top_n_pairs(pos_texts, neg_texts, pos_emb, neg_emb, n, mode='similar'):
    """
    Wybiera n par z podanej puli metodą greedy (bez powtórzeń).
    mode='similar'   → pary o najwyższej korelacji Spearmana
    mode='different' → pary o najniższej korelacji Spearmana

    Zwraca:
        selected_pos  – lista wybranych tekstów pozytywnych
        selected_neg  – lista wybranych tekstów negatywnych
        similarities  – lista wartości korelacji dla wybranych par
        remaining_*   – zaktualizowane listy/macierze po usunięciu użytych elementów
    """
    pos_texts = list(pos_texts)
    neg_texts = list(neg_texts)
    pos_emb   = pos_emb.copy()
    neg_emb   = neg_emb.copy()

    selected_pos, selected_neg, similarities = [], [], []

    for _ in range(n):
        if len(pos_texts) == 0 or len(neg_texts) == 0:
            break

        sim_matrix = build_similarity_matrix(pos_emb, neg_emb)

        if mode == 'similar':
            pos_idx, neg_idx = np.unravel_index(
                np.argmax(sim_matrix), sim_matrix.shape
            )
        else:
            pos_idx, neg_idx = np.unravel_index(
                np.argmin(sim_matrix), sim_matrix.shape
            )

        pos_idx, neg_idx = int(pos_idx), int(neg_idx)
        similarities.append(sim_matrix[pos_idx, neg_idx])
        selected_pos.append(pos_texts[pos_idx])
        selected_neg.append(neg_texts[neg_idx])

        pos_texts.pop(pos_idx)
        neg_texts.pop(neg_idx)
        pos_emb = np.delete(pos_emb, pos_idx, axis=0)
        neg_emb = np.delete(neg_emb, neg_idx, axis=0)

    return selected_pos, selected_neg, similarities, pos_texts, neg_texts, pos_emb, neg_emb



def collect_texts_for_keys(semantic_features_list, pos_key, neg_key):
    """
    Pobiera teksty z listy słowników.
    Obsługuje zarówno wartości będące stringiem jak i listą [string].
    """
    positive_texts = []
    negative_texts = []

    for data in semantic_features_list:
        pos_val = data[pos_key]
        neg_val = data[neg_key]

        # POPRAWKA 1: obsługa obu formatów — string i [string]
        positive_texts.append(pos_val[0] if isinstance(pos_val, list) else pos_val)
        negative_texts.append(neg_val[0] if isinstance(neg_val, list) else neg_val)

    return positive_texts, negative_texts



coronavirus_domains_one = {
    'stance':     ('vaccine_stance_base',         'vaccine_stance_opposite'),
}


QUANTITY_OF_SEMANTIC_FEATURES = 50
TOP_N_PAIRS = 10
OUTPUT_FILE = "resulsts_vaccine_OpenAI_ONE.txt"

_module_globals = globals()
semantic_features_list = []
for i in range(1, QUANTITY_OF_SEMANTIC_FEATURES + 1):
    key = f'semantic_features_v{i}'
    if key not in _module_globals:
        raise NameError(
            f"Nie znaleziono zmiennej '{key}' — sprawdź czy import * eksponuje tę zmienną."
        )
    semantic_features_list.append(_module_globals[key])


open(OUTPUT_FILE, "w", encoding="utf-8").close()



for domain, (pos_key, neg_key) in coronavirus_domains_one.items():
    print(f"\n{'='*60}")
    # if domain == "safety":
    #     continue
    # if domain == "efficacy":
    #     continue
    print(f"DOMAIN: {domain.upper()}")
    print(f"{'='*60}")

    pos_texts, neg_texts = collect_texts_for_keys(
        semantic_features_list, pos_key, neg_key
    )

    # Deduplikacja: usuwa powtórzenia zachowując kolejność
    pos_texts = list(dict.fromkeys(pos_texts))
    neg_texts = list(dict.fromkeys(neg_texts))

    print(f"Po deduplikacji — pos: {len(pos_texts)}, neg: {len(neg_texts)}")

    print("Generowanie embeddingów…")
    pos_emb = encode_texts_with_gemini(pos_texts)
    neg_emb = encode_texts_with_gemini(neg_texts)

    print(f"\n--- SIMILAR PAIRS (top {TOP_N_PAIRS}) ---")
    (sim_pos, sim_neg, sim_scores,
     rem_pos_texts, rem_neg_texts,
     rem_pos_emb, rem_neg_emb) = select_top_n_pairs(
        pos_texts, neg_texts, pos_emb, neg_emb,
        n=TOP_N_PAIRS, mode='similar'
    )

    for rank, (pt, nt, score) in enumerate(zip(sim_pos, sim_neg, sim_scores), 1):
        print(f"  #{rank}  Spearman={score:.4f}")
        print(f"       Positive: \"{pt}\"")
        print(f"       Negative: \"{nt}\"")

    print(f"\n--- DIFFERENT PAIRS (top {TOP_N_PAIRS}, z pozostałych {len(rem_pos_texts)} tekstów) ---")
    (diff_pos, diff_neg, diff_scores,
     _, _, _, _) = select_top_n_pairs(
        rem_pos_texts, rem_neg_texts, rem_pos_emb, rem_neg_emb,
        n=TOP_N_PAIRS, mode='different'
    )

    for rank, (pt, nt, score) in enumerate(zip(diff_pos, diff_neg, diff_scores), 1):
        print(f"  #{rank}  Spearman={score:.4f}")
        print(f"       Positive: \"{pt}\"")
        print(f"       Negative: \"{nt}\"")

    for pos_features, neg_features, label in [
        (sim_pos,  sim_neg,  "SIMILAR"),
        (diff_pos, diff_neg, "DIFFERENT"),
    ]:
        with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
            f.write(f"\n--- DOMAIN: {domain.upper()} | {label} ---\n")
            f.write("=" * 60 + "\n")
            f.write(f"positive\n{pos_features}\n")
            f.write("-" * 30 + "\n")
            f.write(f"negative\n{neg_features}\n")
            f.write("=" * 60 + "\n")

# %% [markdown]
# ### Input texts stats

# %%
import math
from collections import Counter

def calculate_text_stats(texts_list):
    """
    Oblicza statystyki dla listy tekstów:
    - CTTR (Corrected Type-Token Ratio): średni, maksymalny, minimalny, mediana
    - Entropia: średnia, maksymalna, minimalna, mediana
    
    CTTR = unique_words / sqrt(2 * total_words)
    Entropia = -suma(p_i * log2(p_i)) dla każdego słowa i, gdzie p_i to prawdopodobieństwo wystąpienia słowa
    
    Args:
        texts_list (list): Lista stringów, gdzie każdy string to oddzielny tekst.
        
    Returns:
        dict: Słownik zawierający statystyki CTTR i entropii
    """
    if not texts_list:
        return {
            "cttr": {"avg": 0.0, "max": 0.0, "min": 0.0, "median": 0.0},
            "entropy": {"avg": 0.0, "max": 0.0, "min": 0.0, "median": 0.0},
            "details": []
        }
    
    cttr_values = []
    entropy_values = []
    details = []
    
    for text in texts_list:
        # Tokenizacja tekstu (prosta implementacja - podział po białych znakach)
        words = text.lower().split()
        
        # Obliczenie liczby słów i unikalnych słów
        total_words = len(words)
        unique_words = len(set(words))
        
        # Obliczenie CTTR
        if total_words == 0:
            cttr = 0.0
        else:
            cttr = unique_words / math.sqrt(2 * total_words)
        
        # Obliczenie entropii
        if total_words == 0:
            entropy = 0.0
        else:
            # Liczenie wystąpień każdego słowa
            word_counts = Counter(words)
            
            # Obliczenie prawdopodobieństwa wystąpienia każdego słowa
            probabilities = [count / total_words for count in word_counts.values()]
            
            # Obliczenie entropii (w bitach, używając logarytmu o podstawie 2)
            entropy = -sum(p * math.log2(p) for p in probabilities)
        
        cttr_values.append(cttr)
        entropy_values.append(entropy)
        
        # Zapisanie szczegółów dla każdego tekstu
        details.append({
            "total_words": total_words,
            "unique_words": unique_words,
            "cttr": cttr,
            "entropy": entropy,
            "preview": " ".join(words[:10]) + ("..." if len(words) > 10 else "")
        })
    
    # Obliczenie statystyk dla CTTR
    cttr_stats = {
        "avg": sum(cttr_values) / len(cttr_values),
        "max": max(cttr_values),
        "min": min(cttr_values),
        "median": calculate_median(cttr_values)
    }
    
    # Obliczenie statystyk dla entropii
    entropy_stats = {
        "avg": sum(entropy_values) / len(entropy_values),
        "max": max(entropy_values),
        "min": min(entropy_values),
        "median": calculate_median(entropy_values)
    }
    
    return {
        "cttr": cttr_stats,
        "entropy": entropy_stats,
        "details": details
    }

def calculate_median(values):
    """
    Oblicza medianę z listy wartości.
    
    Args:
        values (list): Lista wartości liczbowych
        
    Returns:
        float: Mediana listy
    """
    sorted_values = sorted(values)
    n = len(sorted_values)
    if n % 2 == 0:
        return (sorted_values[n//2-1] + sorted_values[n//2]) / 2
    else:
        return sorted_values[n//2]

def demonstrate_text_analysis():
    stats = calculate_text_stats(all_conent_from_pages)
    
    print("Statystyki zbiorcze:")
    print("\nCTTR:")
    print(f"  Średni: {stats['cttr']['avg']:.4f}")
    print(f"  Maksymalny: {stats['cttr']['max']:.4f}")
    print(f"  Minimalny: {stats['cttr']['min']:.4f}")
    print(f"  Mediana: {stats['cttr']['median']:.4f}")
    
    print("\nEntropia:")
    print(f"  Średnia: {stats['entropy']['avg']:.4f}")
    print(f"  Maksymalna: {stats['entropy']['max']:.4f}")
    print(f"  Minimalna: {stats['entropy']['min']:.4f}")
    print(f"  Mediana: {stats['entropy']['median']:.4f}")
    
    print("\nSzczegółowa analiza każdego tekstu:")
    for i, detail in enumerate(stats['details'], 1):
        print(f"Tekst {i}:")
        print(f"  Liczba słów: {detail['total_words']}")
        print(f"  Liczba unikalnych słów: {detail['unique_words']}")
        print(f"  CTTR: {detail['cttr']:.4f}")
        print(f"  Entropia: {detail['entropy']:.4f} bitów")
        print(f"  Początek: {detail['preview']}")
        print()

demonstrate_text_analysis()
# Out:
# Statystyki zbiorcze:
#
# CTTR:
#   Średni: 5.3798
#   Maksymalny: 9.5077
#   Minimalny: 3.1299
#   Mediana: 5.0136
#
# Entropia:
#   Średnia: 5.9924
#   Maksymalna: 7.6330
#   Minimalna: 4.4586
#   Mediana: 5.8581
#
# Szczegółowa analiza każdego tekstu:
# Tekst 1:
#   Liczba słów: 161
#   Liczba unikalnych słów: 114
#   CTTR: 6.3530
#   Entropia: 6.4648 bitów
#   Początek: that’s how health journalist helen branswell recently described the vaccines...
#
# Tekst 2:
#   Liczba słów: 162
#   Liczba unikalnych słów: 128
#   CTTR: 7.1111
#   Entropia: 6.7996 bitów
#   Początek: but once the novel coronavirus was discovered and sequenced in...
#
# Tekst 3:
#   Liczba słów: 243
#   Liczba unikalnych słów: 144
#   CTTR: 6.5320
#   Entropia: 6.7472 bitów
#   Początek: “the first time your body sees the spike protein, it...
#
# Tekst 4:
#   Liczba słów: 202
#   Liczba unikalnych słów: 127
#   CTTR: 6.3185
#   Entropia: 6.5685 bitów
#   Początek: vaccine trials often take years because not only do they...
#
# Tekst 5:
#   Liczba słów: 116
#   Liczba unikalnych słów: 86
#   CTTR: 5.6462
#   Entropia: 6.2285 bitów
#   Początek: some vaccines, such as the measles or oral polio vaccines,...
#
# Tekst 6:
#   Liczba słów: 208
#   Liczba unikalnych słów: 103
#   CTTR: 5.0500
#   Entropia: 6.0187 bitów
#   Początek: a vaccine’s efficacy is measured in a controlled clinical trial...
#
# Tekst 7:
#   Liczba słów: 61
#   Liczba unikalnych słów: 53
#   CTTR: 4.7984
#   Entropia: 5.6437 bitów
#   Początek: one vaccine ingredient that has been studied specifically is thimerosal....
#
# Tekst 8:
#   Liczba słów: 78
#   Liczba unikalnych słów: 56
#   CTTR: 4.4836
#   Entropia: 5.4791 bitów
#   Początek: can the dramatic increase in autism be ascribed to change...
#
# Tekst 9:
#   Liczba słów: 146
#   Liczba unikalnych słów: 103
#   CTTR: 6.0276
#   Entropia: 6.4271 bitów
#   Początek: when there is very little or no covid-19 disease in...
#
# Tekst 10:
#   Liczba słów: 127
#   Liczba unikalnych słów: 91
#   CTTR: 5.7098
#   Entropia: 6.3045 bitów
#   Początek: when you are vaccinated against covid-19, you not only protect...
#
# Tekst 11:
#   Liczba słów: 160
#   Liczba unikalnych słów: 103
#   CTTR: 5.7579
#   Entropia: 6.3790 bitów
#   Początek: accordingly, in addition to its role in protecting them from...
#
# Tekst 12:
#   Liczba słów: 74
#   Liczba unikalnych słów: 59
#   CTTR: 4.8498
#   Entropia: 5.7836 bitów
#   Początek: recent data suggest covid-19 vaccines become less effective at preventing...
#
# Tekst 13:
#   Liczba słów: 49
#   Liczba unikalnych słów: 39
#   CTTR: 3.9396
#   Entropia: 5.1757 bitów
#   Początek: viruses are constantly changing, including the virus that causes covid-19....
#
# Tekst 14:
#   Liczba słów: 51
#   Liczba unikalnych słów: 47
#   CTTR: 4.6537
#   Entropia: 5.5156 bitów
#   Początek: even if you’ve had covid-19, experts recommend getting vaccinated —...
#
# Tekst 15:
#   Liczba słów: 74
#   Liczba unikalnych słów: 61
#   CTTR: 5.0142
#   Entropia: 5.7938 bitów
#   Początek: vaccines do not give you a disease. instead, they teach...
#
# Tekst 16:
#   Liczba słów: 90
#   Liczba unikalnych słów: 67
#   CTTR: 4.9939
#   Entropia: 5.7858 bitów
#   Początek: additionally, there are serious health risks associated with the vaccine...
#
# Tekst 17:
#   Liczba słów: 41
#   Liczba unikalnych słów: 33
#   CTTR: 3.6442
#   Entropia: 4.8793 bitów
#   Początek: another concern stems from the fact that the covid-19 vaccine...
#
# Tekst 18:
#   Liczba słów: 66
#   Liczba unikalnych słów: 57
#   CTTR: 4.9612
#   Entropia: 5.7055 bitów
#   Początek: but clinical trial results demonstrate the vaccine’s safety in young...
#
# Tekst 19:
#   Liczba słów: 67
#   Liczba unikalnych słów: 57
#   CTTR: 4.9241
#   Entropia: 5.6534 bitów
#   Początek: beyond concerns about side effects, many of the hesitant just...
#
# Tekst 20:
#   Liczba słów: 71
#   Liczba unikalnych słów: 57
#   CTTR: 4.7833
#   Entropia: 5.7059 bitów
#   Początek: for some, the concern is the vaccine itself — and...
#
# Tekst 21:
#   Liczba słów: 66
#   Liczba unikalnych słów: 55
#   CTTR: 4.7871
#   Entropia: 5.6767 bitów
#   Początek: the first reason relates to the view that healthcare is...
#
# Tekst 22:
#   Liczba słów: 81
#   Liczba unikalnych słów: 62
#   CTTR: 4.8712
#   Entropia: 5.8181 bitów
#   Początek: the second reason relates to the impact of social exclusion....
#
# Tekst 23:
#   Liczba słów: 63
#   Liczba unikalnych słów: 48
#   CTTR: 4.2762
#   Entropia: 5.4136 bitów
#   Początek: some people have had concerns that asd might be linked...
#
# Tekst 24:
#   Liczba słów: 94
#   Liczba unikalnych słów: 70
#   CTTR: 5.1053
#   Entropia: 5.9148 bitów
#   Początek: based on the extensive review presented, gacvs concluded that no...
#
# Tekst 25:
#   Liczba słów: 45
#   Liczba unikalnych słów: 39
#   CTTR: 4.1110
#   Entropia: 5.1640 bitów
#   Początek: opponents say that children’s immune systems can deal with most...
#
# Tekst 26:
#   Liczba słów: 89
#   Liczba unikalnych słów: 70
#   CTTR: 5.2467
#   Entropia: 6.0064 bitów
#   Początek: vaccines can save children’s lives. the american academy of pediatrics...
#
# Tekst 27:
#   Liczba słów: 149
#   Liczba unikalnych słów: 86
#   CTTR: 4.9818
#   Entropia: 5.9422 bitów
#   Początek: the ingredients in vaccines are safe in the amounts used....
#
# Tekst 28:
#   Liczba słów: 64
#   Liczba unikalnych słów: 51
#   CTTR: 4.5078
#   Entropia: 5.5020 bitów
#   Początek: major medical organizations state that vaccines are safe. these organizations...
#
# Tekst 29:
#   Liczba słów: 62
#   Liczba unikalnych słów: 50
#   CTTR: 4.4901
#   Entropia: 5.5306 bitów
#   Początek: vaccines protect future generations. vaccinated mothers protect their unborn children...
#
# Tekst 30:
#   Liczba słów: 92
#   Liczba unikalnych słów: 68
#   CTTR: 5.0130
#   Entropia: 5.8723 bitów
#   Początek: vaccines can cause serious and sometimes fatal side effects. according...
#
# Tekst 31:
#   Liczba słów: 102
#   Liczba unikalnych słów: 68
#   CTTR: 4.7610
#   Entropia: 5.8157 bitów
#   Początek: vaccines contain harmful ingredients. aluminum is used in some vaccines...
#
# Tekst 32:
#   Liczba słów: 83
#   Liczba unikalnych słów: 48
#   CTTR: 3.7255
#   Entropia: 5.2108 bitów
#   Początek: most diseases that vaccines target are relatively harmless in many...
#
# Tekst 33:
#   Liczba słów: 52
#   Liczba unikalnych słów: 37
#   CTTR: 3.6281
#   Entropia: 5.0321 bitów
#   Początek: vaccines are considered to be safe. they’re rigorously tested and...
#
# Tekst 34:
#   Liczba słów: 65
#   Liczba unikalnych słów: 49
#   CTTR: 4.2976
#   Entropia: 5.4261 bitów
#   Początek: vaccination is one of the most successful public health interventions...
#
# Tekst 35:
#   Liczba słów: 77
#   Liczba unikalnych słów: 57
#   CTTR: 4.5932
#   Entropia: 5.6106 bitów
#   Początek: some of the pros of mandatory vaccinations at work include:covid-19...
#
# Tekst 36:
#   Liczba słów: 50
#   Liczba unikalnych słów: 39
#   CTTR: 3.9000
#   Entropia: 5.1337 bitów
#   Początek: covid-19 vaccines have been shown to be safe and effective....
#
# Tekst 37:
#   Liczba słów: 69
#   Liczba unikalnych słów: 54
#   CTTR: 4.5968
#   Entropia: 5.6229 bitów
#   Początek: vaccines can have side effects, that is a fact. but...
#
# Tekst 38:
#   Liczba słów: 51
#   Liczba unikalnych słów: 40
#   CTTR: 3.9606
#   Entropia: 5.1870 bitów
#   Początek: if we take one of these licensed vaccines, we not...
#
# Tekst 39:
#   Liczba słów: 141
#   Liczba unikalnych słów: 100
#   CTTR: 5.9549
#   Entropia: 6.3256 bitów
#   Początek: so vaccines are not safe by design. safety by testing...
#
# Tekst 40:
#   Liczba słów: 260
#   Liczba unikalnych słów: 165
#   CTTR: 7.2357
#   Entropia: 6.9649 bitów
#   Początek: since the covid-19 vaccines have been released under the emergency...
#
# Tekst 41:
#   Liczba słów: 106
#   Liczba unikalnych słów: 79
#   CTTR: 5.4257
#   Entropia: 6.1061 bitów
#   Początek: research into immunisation has been based on the theory that...
#
# Tekst 42:
#   Liczba słów: 71
#   Liczba unikalnych słów: 63
#   CTTR: 5.2868
#   Entropia: 5.9031 bitów
#   Początek: in general, skipping vaccines isn't a good idea. this can...
#
# Tekst 43:
#   Liczba słów: 91
#   Liczba unikalnych słów: 64
#   CTTR: 4.7440
#   Entropia: 5.6736 bitów
#   Początek: any vaccine can cause side effects. usually, these side effects...
#
# Tekst 44:
#   Liczba słów: 264
#   Liczba unikalnych słów: 163
#   CTTR: 7.0937
#   Entropia: 6.8321 bitów
#   Początek: the official narrative is collapsing. the winter of 2022 was...
#
# Tekst 45:
#   Liczba słów: 220
#   Liczba unikalnych słów: 122
#   CTTR: 5.8161
#   Entropia: 6.3563 bitów
#   Początek: vaccinated individuals have accounted for 73 percent of all covid-19...
#
# Tekst 46:
#   Liczba słów: 209
#   Liczba unikalnych słów: 141
#   CTTR: 6.8965
#   Entropia: 6.7635 bitów
#   Początek: as the epoch times and other media outlets reported yesterday,...
#
# Tekst 47:
#   Liczba słów: 154
#   Liczba unikalnych słów: 102
#   CTTR: 5.8120
#   Entropia: 6.3015 bitów
#   Początek: the genetic material delivered by mrna vaccines never enters the...
#
# Tekst 48:
#   Liczba słów: 226
#   Liczba unikalnych słów: 171
#   CTTR: 8.0432
#   Entropia: 7.1712 bitów
#   Początek: new york-based physician dr. vladimir “zev” zelenko warned that anyone...
#
# Tekst 49:
#   Liczba słów: 247
#   Liczba unikalnych słów: 161
#   CTTR: 7.2437
#   Entropia: 6.9726 bitów
#   Początek: physician and author dr. jane ruby exposed the gross incompetence...
#
# Tekst 50:
#   Liczba słów: 224
#   Liczba unikalnych słów: 132
#   CTTR: 6.2364
#   Entropia: 6.5819 bitów
#   Początek: ruby noted that most of the people giving the covid...
#
# Tekst 51:
#   Liczba słów: 190
#   Liczba unikalnych słów: 131
#   CTTR: 6.7202
#   Entropia: 6.6330 bitów
#   Początek: for now, those who believe in the overwhelmingly debunked theories...
#
# Tekst 52:
#   Liczba słów: 272
#   Liczba unikalnych słów: 173
#   CTTR: 7.4173
#   Entropia: 6.9485 bitów
#   Początek: it is true that the production of all three of...
#
# Tekst 53:
#   Liczba słów: 207
#   Liczba unikalnych słów: 136
#   CTTR: 6.6840
#   Entropia: 6.7132 bitów
#   Początek: thalidomide is a drug that was marketed as a treatment...
#
# Tekst 54:
#   Liczba słów: 84
#   Liczba unikalnych słów: 65
#   CTTR: 5.0149
#   Entropia: 5.8892 bitów
#   Początek: there are unfortunate and disturbing reports that childhood vaccine administration...
#
# Tekst 55:
#   Liczba słów: 55
#   Liczba unikalnych słów: 43
#   CTTR: 4.0999
#   Entropia: 5.2293 bitów
#   Początek: yes. the two mrna vaccines, pfizer and moderna, authorized by...
#
# Tekst 56:
#   Liczba słów: 57
#   Liczba unikalnych słów: 46
#   CTTR: 4.3083
#   Entropia: 5.4337 bitów
#   Początek: covid-19 vaccines have proven to be safe, effective and life-saving....
#
# Tekst 57:
#   Liczba słów: 27
#   Liczba unikalnych słów: 23
#   CTTR: 3.1299
#   Entropia: 4.4586 bitów
#   Początek: a covid-19 vaccine might: protect you from getting covid-19, prevent...
#
# Tekst 58:
#   Liczba słów: 51
#   Liczba unikalnych słów: 41
#   CTTR: 4.0596
#   Entropia: 5.2359 bitów
#   Początek: proponents say that vaccination is safe and one of the...
#
# Tekst 59:
#   Liczba słów: 175
#   Liczba unikalnych słów: 111
#   CTTR: 5.9332
#   Entropia: 6.5002 bitów
#   Początek: parental refusal of vaccines is a growing a concern for...
#
# Tekst 60:
#   Liczba słów: 142
#   Liczba unikalnych słów: 90
#   CTTR: 5.3405
#   Entropia: 6.1598 bitów
#   Początek: i just finished watching the “stop the mandate” march in...
#
# Tekst 61:
#   Liczba słów: 133
#   Liczba unikalnych słów: 96
#   CTTR: 5.8861
#   Entropia: 6.3174 bitów
#   Początek: proponents of vaccine mandates typically claim that everyone who can...
#
# Tekst 62:
#   Liczba słów: 45
#   Liczba unikalnych słów: 40
#   CTTR: 4.2164
#   Entropia: 5.2696 bitów
#   Początek: childhood vaccines protect children from a variety of serious or...
#
# Tekst 63:
#   Liczba słów: 91
#   Liczba unikalnych słów: 64
#   CTTR: 4.7440
#   Entropia: 5.6736 bitów
#   Początek: any vaccine can cause side effects. usually, these side effects...
#
# Tekst 64:
#   Liczba słów: 35
#   Liczba unikalnych słów: 34
#   CTTR: 4.0638
#   Entropia: 5.0721 bitów
#   Początek: i feel that a vaccine is a huge intervention in...
#
# Tekst 65:
#   Liczba słów: 47
#   Liczba unikalnych słów: 40
#   CTTR: 4.1257
#   Entropia: 5.1981 bitów
#   Początek: some people don’t get flu vaccines for themselves or for...
#
# Tekst 66:
#   Liczba słów: 30
#   Liczba unikalnych słów: 28
#   CTTR: 3.6148
#   Entropia: 4.7736 bitów
#   Początek: the advantages of immunisation are obvious - they stop individuals...
#
# Tekst 67:
#   Liczba słów: 57
#   Liczba unikalnych słów: 46
#   CTTR: 4.3083
#   Entropia: 5.4337 bitów
#   Początek: in recent years there has been much controversy surrounding the...
#
# Tekst 68:
#   Liczba słów: 39
#   Liczba unikalnych słów: 34
#   CTTR: 3.8497
#   Entropia: 5.0290 bitów
#   Początek: covid-19 vaccines are safe, and getting vaccinated will help protect...
#
# Tekst 69:
#   Liczba słów: 132
#   Liczba unikalnych słów: 97
#   CTTR: 5.9699
#   Entropia: 6.3240 bitów
#   Początek: studies show that vaccines are necessary for children to fight...
#
# Tekst 70:
#   Liczba słów: 91
#   Liczba unikalnych słów: 72
#   CTTR: 5.3370
#   Entropia: 5.9086 bitów
#   Początek: the world health organization (who) not only advises that vaccines...
#
# Tekst 71:
#   Liczba słów: 77
#   Liczba unikalnych słów: 60
#   CTTR: 4.8349
#   Entropia: 5.7277 bitów
#   Początek: the australian government says vaccination is the most effective way...
#
# Tekst 72:
#   Liczba słów: 67
#   Liczba unikalnych słów: 51
#   CTTR: 4.4057
#   Entropia: 5.5361 bitów
#   Początek: a new study has also found a reduction in transmission...
#
# Tekst 73:
#   Liczba słów: 89
#   Liczba unikalnych słów: 66
#   CTTR: 4.9469
#   Entropia: 5.8438 bitów
#   Początek: because of advances in medical science, your child can be...
#
# Tekst 74:
#   Liczba słów: 83
#   Liczba unikalnych słów: 65
#   CTTR: 5.0450
#   Entropia: 5.8314 bitów
#   Początek: vaccines are only given to children after a long and...
#
# Tekst 75:
#   Liczba słów: 128
#   Liczba unikalnych słów: 93
#   CTTR: 5.8125
#   Entropia: 6.3211 bitów
#   Początek: children in the u.s. still get still get vaccine-preventable diseases....
#
# Tekst 76:
#   Liczba słów: 78
#   Liczba unikalnych słów: 61
#   CTTR: 4.8839
#   Entropia: 5.7839 bitów
#   Początek: a child with a vaccine-preventable disease can be denied attendance...
#
# Tekst 77:
#   Liczba słów: 120
#   Liczba unikalnych słów: 87
#   CTTR: 5.6158
#   Entropia: 6.2382 bitów
#   Początek: vaccines have reduced and, in some cases, eliminated many diseases...
#
# Tekst 78:
#   Liczba słów: 68
#   Liczba unikalnych słów: 51
#   CTTR: 4.3732
#   Entropia: 5.4939 bitów
#   Początek: who's strategic advisory group of experts (sage) has concluded that...
#
# Tekst 79:
#   Liczba słów: 139
#   Liczba unikalnych słów: 98
#   CTTR: 5.8776
#   Entropia: 6.3733 bitów
#   Początek: covid-19 is a coronavirus (like a cold). all coronaviruses can...
#
# Tekst 80:
#   Liczba słów: 140
#   Liczba unikalnych słów: 96
#   CTTR: 5.7371
#   Entropia: 6.2601 bitów
#   Początek: after 2 years of covid ravaging america, less than 1...
#
# Tekst 81:
#   Liczba słów: 91
#   Liczba unikalnych słów: 66
#   CTTR: 4.8922
#   Entropia: 5.8113 bitów
#   Początek: according to the cdc’s own numbers, covid-19 has a 99.74%...
#
# Tekst 82:
#   Liczba słów: 112
#   Liczba unikalnych słów: 73
#   CTTR: 4.8775
#   Entropia: 5.8847 bitów
#   Początek: since the vaccinated can still get the virus, if the...
#
# Tekst 83:
#   Liczba słów: 78
#   Liczba unikalnych słów: 53
#   CTTR: 4.2434
#   Entropia: 5.5131 bitów
#   Początek: these vaccines, by definition, are not vaccines, but medical treatments....
#
# Tekst 84:
#   Liczba słów: 69
#   Liczba unikalnych słów: 54
#   CTTR: 4.5968
#   Entropia: 5.6229 bitów
#   Początek: why are these numbers immediately discounted as being unconnected, with...
#
# Tekst 85:
#   Liczba słów: 61
#   Liczba unikalnych słów: 40
#   CTTR: 3.6214
#   Entropia: 4.9689 bitów
#   Początek: the three manufacturers, pfizer, moderna, and johnson & johnson have...
#
# Tekst 86:
#   Liczba słów: 197
#   Liczba unikalnych słów: 142
#   CTTR: 7.1539
#   Entropia: 6.8256 bitów
#   Początek: most patients, however, are unaware that among relevant scientific experts...
#
# Tekst 87:
#   Liczba słów: 171
#   Liczba unikalnych słów: 119
#   CTTR: 6.4348
#   Entropia: 6.4622 bitów
#   Początek: perhaps the most pertinent finding is that, due to the...
#
# Tekst 88:
#   Liczba słów: 258
#   Liczba unikalnych słów: 163
#   CTTR: 7.1757
#   Entropia: 6.9393 bitów
#   Początek: the implications for doctors and patients are that: vaccination against...
#
# Tekst 89:
#   Liczba słów: 322
#   Liczba unikalnych słów: 201
#   CTTR: 7.9205
#   Entropia: 7.2415 bitów
#   Początek: but what about the second and third waves of “cases”,...
#
# Tekst 90:
#   Liczba słów: 396
#   Liczba unikalnych słów: 216
#   CTTR: 7.6752
#   Entropia: 7.1815 bitów
#   Początek: while the now clearly established widespread cross-immunity against sars-cov-2 implies...
#
# Tekst 91:
#   Liczba słów: 347
#   Liczba unikalnych słów: 204
#   CTTR: 7.7437
#   Entropia: 7.0838 bitów
#   Początek: this immune reaction will in principle resemble that to an...
#
# Tekst 92:
#   Liczba słów: 217
#   Liczba unikalnych słów: 145
#   CTTR: 6.9602
#   Entropia: 6.6572 bitów
#   Początek: 2.4.2. delivering the spike protein into the bloodstream a dire...
#
# Tekst 93:
#   Liczba słów: 427
#   Liczba unikalnych słów: 253
#   CTTR: 8.6575
#   Entropia: 7.2648 bitów
#   Początek: a dire danger of covid-19 vaccines is that spike proteins...
#
# Tekst 94:
#   Liczba słów: 150
#   Liczba unikalnych słów: 102
#   CTTR: 5.8890
#   Entropia: 6.3489 bitów
#   Początek: 2.4.3. attacking the vessel walls: clotting and leaky vessels while...
#
# Tekst 95:
#   Liczba słów: 606
#   Liczba unikalnych słów: 331
#   CTTR: 9.5077
#   Entropia: 7.6330 bitów
#   Początek: 2.4.3.2. antibodies before the new discoveries of 2021, scientists’ concerns...
#
# Tekst 96:
#   Liczba słów: 167
#   Liczba unikalnych słów: 120
#   CTTR: 6.5661
#   Entropia: 6.6663 bitów
#   Początek: 2.4.3.3. complement recent findings indicate that complement activation is a...
#
# Tekst 97:
#   Liczba słów: 171
#   Liczba unikalnych słów: 112
#   CTTR: 6.0563
#   Entropia: 6.4190 bitów
#   Początek: 2.4.3.4. leaky vessels—the promise of booster shots given that booster...
#
# Tekst 98:
#   Liczba słów: 109
#   Liczba unikalnych słów: 85
#   CTTR: 5.7569
#   Entropia: 6.1485 bitów
#   Początek: 2.4.4. enhancing the severity of wild coronavirus infection finally, as...
#
# Tekst 99:
#   Liczba słów: 296
#   Liczba unikalnych słów: 175
#   CTTR: 7.1925
#   Entropia: 6.9213 bitów
#   Początek: implications for doctors and patients although vaccine manufacturers and regulators...
#
# Tekst 100:
#   Liczba słów: 61
#   Liczba unikalnych słów: 54
#   CTTR: 4.8889
#   Entropia: 5.6889 bitów
#   Początek: my friend and tennis partner, a mid fifties very fit...
#
# Tekst 101:
#   Liczba słów: 77
#   Liczba unikalnych słów: 60
#   CTTR: 4.8349
#   Entropia: 5.7698 bitów
#   Początek: he added that some vaccine recipients suffered from serious adverse...
#
# Tekst 102:
#   Liczba słów: 129
#   Liczba unikalnych słów: 93
#   CTTR: 5.7899
#   Entropia: 6.3087 bitów
#   Początek: the cardiologist warned that young people should steer clear of...
#
# Tekst 103:
#   Liczba słów: 162
#   Liczba unikalnych słów: 110
#   CTTR: 6.1111
#   Entropia: 6.4154 bitów
#   Początek: cls is an extremely rare, serious condition that causes fluid...
#
# Tekst 104:
#   Liczba słów: 116
#   Liczba unikalnych słów: 87
#   CTTR: 5.7118
#   Entropia: 6.2426 bitów
#   Początek: “we will have a safety profile for only a certain...
#
# Tekst 105:
#   Liczba słów: 112
#   Liczba unikalnych słów: 77
#   CTTR: 5.1448
#   Entropia: 6.0017 bitów
#   Początek: hundreds of nebraska physicians and health care providers have signed...
#
# Tekst 106:
#   Liczba słów: 165
#   Liczba unikalnych słów: 115
#   CTTR: 6.3305
#   Entropia: 6.6020 bitów
#   Początek: “we're seeing a trend; kids who are not yet vaccinated...
#
# Tekst 107:
#   Liczba słów: 175
#   Liczba unikalnych słów: 114
#   CTTR: 6.0936
#   Entropia: 6.5273 bitów
#   Początek: sharon stoolman, m.d., a pediatric hospitalist at children’s, said she...
#
# Tekst 108:
#   Liczba słów: 236
#   Liczba unikalnych słów: 152
#   CTTR: 6.9964
#   Entropia: 6.8181 bitów
#   Początek: health care providers are the absolute best source for health...
#
# Tekst 109:
#   Liczba słów: 175
#   Liczba unikalnych słów: 121
#   CTTR: 6.4677
#   Entropia: 6.6495 bitów
#   Początek: “in addition to masking, washing your hands and social distancing,...
#
# Tekst 110:
#   Liczba słów: 85
#   Liczba unikalnych słów: 65
#   CTTR: 4.9853
#   Entropia: 5.8373 bitów
#   Początek: pharmaceutical industry expert professor frank lichtenberg estimates that the value...
#
# Tekst 111:
#   Liczba słów: 129
#   Liczba unikalnych słów: 97
#   CTTR: 6.0390
#   Entropia: 6.3397 bitów
#   Początek: what is currently unknown is the ultimate impact of those...
#
# Tekst 112:
#   Liczba słów: 87
#   Liczba unikalnych słów: 64
#   CTTR: 4.8518
#   Entropia: 5.8007 bitów
#   Początek: “vaccination is as important for adults as it is for...
#
# Tekst 113:
#   Liczba słów: 65
#   Liczba unikalnych słów: 52
#   CTTR: 4.5607
#   Entropia: 5.5568 bitów
#   Początek: 1. you may no longer be protected. you may have...
#
# Tekst 114:
#   Liczba słów: 69
#   Liczba unikalnych słów: 60
#   CTTR: 5.1075
#   Entropia: 5.8077 bitów
#   Początek: 2. getting vaccines helps protect your kids -- especially babies...
#
# Tekst 115:
#   Liczba słów: 79
#   Liczba unikalnych słów: 60
#   CTTR: 4.7733
#   Entropia: 5.6629 bitów
#   Początek: 4. you may need them when you travel. headed to...
#
# Tekst 116:
#   Liczba słów: 63
#   Liczba unikalnych słów: 51
#   CTTR: 4.5434
#   Entropia: 5.5286 bitów
#   Początek: 5. everyone needs a flu vaccine, every year. the cdc...
#
# Tekst 117:
#   Liczba słów: 53
#   Liczba unikalnych słów: 48
#   CTTR: 4.6622
#   Entropia: 5.5392 bitów
#   Początek: 6. your kids have set an example. most children don’t...
#
# Tekst 118:
#   Liczba słów: 76
#   Liczba unikalnych słów: 57
#   CTTR: 4.6233
#   Entropia: 5.6443 bitów
#   Początek: 7. you didn’t get fully vaccinated as a child. not...
#
# Tekst 119:
#   Liczba słów: 67
#   Liczba unikalnych słów: 52
#   CTTR: 4.4921
#   Entropia: 5.5845 bitów
#   Początek: 9. you’re going back to college. the downturn has forced...
#
# Tekst 120:
#   Liczba słów: 59
#   Liczba unikalnych słów: 50
#   CTTR: 4.6029
#   Entropia: 5.5520 bitów
#   Początek: 10. you work in the health care profession. health care...
#
# Tekst 121:
#   Liczba słów: 60
#   Liczba unikalnych słów: 48
#   CTTR: 4.3818
#   Entropia: 5.4691 bitów
#   Początek: 11. you’re sexually active with a number of partners. the...
#
# Tekst 122:
#   Liczba słów: 57
#   Liczba unikalnych słów: 52
#   CTTR: 4.8702
#   Entropia: 5.6310 bitów
#   Początek: 12. you have asthma, heart, lung disease, diabetes, or other...

# %% [markdown]
# ## DVA analysis for DPs

# %%
from sympy import true
from helpers.dva_group import *


if GENERATE_NEW_DVA_ANALYSIS:
    EXTENDED_RESULTS = perform_extended_dva_analysis(SEMANTIC_FEATURES, method=f'{MODEL_IN_USE}', name_of_the_results=f"./{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}", name_of_the_simulation=NAME_OF_SIMULATION)
# Out:
# ----> Przetwarzanie vaccine_stance_base: 20 tekstów
#   Tekst 1/20: This pole represents an evidence-based, institutio...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 2/20: This pole represents an unambiguously PRO-VACCINE ...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 3/20: This pole represents an institutionally-endorsed p...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 4/20: This pole represents an EVIDENCE-BASED, INSTITUTIO...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 5/20: This pole represents an EVIDENCE-BASED, PRO-VACCIN...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 6/20: This pole represents an unambiguously PRO-VACCINE ...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 7/20: This pole represents a PRO-VACCINE stance affirmin...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 8/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 9/20: This pole represents an evidence-based, institutio...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 10/20: This pole represents an EVIDENCE-BASED, INSTITUTIO...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 11/20: This pole represents an evidence-based, institutio...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 12/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 13/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 14/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 15/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 16/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 17/20: This pole represents an EVIDENCE-BASED, INSTITUTIO...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 18/20: This pole represents texts affirming that VACCINES...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 19/20: This pole represents a PRO-VACCINE perspective gro...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 20/20: This pole represents a PRO-VACCINE stance grounded...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Łącznie wygenerowano 20 embeddingów dla vaccine_stance_base
# ----> Przetwarzanie vaccine_stance_opposite: 20 tekstów
#   Tekst 1/20: This pole represents an ANTI-VACCINE stance framin...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 2/20: This pole represents DEEP VACCINE SKEPTICISM asser...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 3/20: This pole represents deep VACCINE SKEPTICISM or ou...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 4/20: This pole represents an ANTI-VACCINE stance charac...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 5/20: This pole represents deep skepticism or outright r...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 6/20: This pole represents a SKEPTICAL ANTI-ESTABLISHMEN...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 7/20: This pole represents a VACCINE-SKEPTICAL stance fr...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 8/20: This pole represents a position of DEEP SKEPTICISM...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 9/20: This pole represents deep INSTITUTIONAL DISTRUST a...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 10/20: This pole represents DEEP VACCINE SKEPTICISM or ou...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 11/20: This pole represents outright rejection of vaccine...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 12/20: This pole represents an ANTI-VACCINE stance driven...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 13/20: This pole represents a deeply skeptical stance ass...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 14/20: This pole represents an ANTI-VACCINE stance rooted...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 15/20: This pole represents an ANTI-VACCINE stance rooted...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 16/20: This pole represents an ANTI-VACCINE stance rooted...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 17/20: This pole represents an ANTI-VACCINE stance rooted...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 18/20: This pole represents texts asserting that VACCINES...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 19/20: This pole represents an ANTI-VACCINE perspective f...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Tekst 20/20: This pole represents an unambiguously ANTI-VACCINE...
# ----> generate_embedding_gemini
#     - Wygenerowano embedding o wymiarze 3072
#   Łącznie wygenerowano 20 embeddingów dla vaccine_stance_opposite
#
# === ROZSZERZONA ANALIZA DVA (GEOMETRYCZNA) ===
#
#
# Domena: vaccine_stance
#   - Liczba embeddingów base: 20
#   - Liczba embeddingów opposite: 20
#   - Liczba analizowanych par: 400
#   - Średnie podobieństwo kosinusowe: 0.8932 ± 0.0163
#   - Średnia różnica projekcji: 0.4609 ± 0.0353
#   - Średnia korelacja Spearmana: 0.7361 ± 0.0386
#   - Średnia korelacja Pearsona: 0.8932 ± 0.0163
#
# === PODSUMOWANIE ROZSZERZONEJ ANALIZY DVA ===
#
# Domena                    | N par  | Cos (μ±σ)       | Proj.Diff (μ±σ)    | Spearman (μ±σ)     | Pearson (μ±σ)
# ------------------------------------------------------------------------------------------------------------------------
# Boxploty rozszerzonej analizy DVA zostały zapisane jako 'extended_dva_boxplots.png'.
# Boxplot projekcji został zapisany jako 'extended_dva_projections_boxplot.png'.
# Heatmapa średnich wartości została zapisana jako 'extended_dva_means_heatmap.png'.
# Tabela statystyk opisowych została zapisana jako 'extended_dva_summary_table.png'.

# %% [markdown]
# ## Setting results variables

# %%
# Tworzenie kopii słownika semantic_features
results_per_feature = SEMANTIC_FEATURES.copy()
result_pages_per_feture = SEMANTIC_FEATURES.copy()

# Dodawanie kategorii _balanced do każdej głównej kategorii
for main_category in list(SEMANTIC_FEATURES.keys()):
    base_category = main_category.split('_')[0] + '_' + main_category.split('_')[1]
    balanced_key = f"{base_category}_balanced"
    print(main_category)
    # Sprawdzenie czy kategoria _balanced już istnieje
    if balanced_key not in results_per_feature:
        results_per_feature[balanced_key] = []
        result_pages_per_feture[balanced_key] = []

# Inicjalizacja pustych list dla wszystkich cech
for feature in results_per_feature:
    results_per_feature[feature] = []
    result_pages_per_feture[feature] = []
    print(results_per_feature[feature])
# Out:
# vaccine_stance_base
# vaccine_stance_opposite
# []
# []
# []

# %% [markdown]
# ## Checkpoints for results

# %%
import json
import hashlib
import os
from pathlib import Path

CHECKPOINT_PATH = Path(f"checkpoints/simulation_checkpoint_{NAME_OF_SIMULATION}.json")

def get_page_id(i: int, page) -> str:
    """Deterministyczny identyfikator strony — indeks + hash treści."""
    content_hash = hashlib.md5(page.page_content.encode()).hexdigest()[:8]
    return f"{i}_{content_hash}"

def save_checkpoint(processed_ids: list, all_results: dict, results_metrics: list):
    """Zapisuje stan pośredni do pliku JSON."""
    CHECKPOINT_PATH.parent.mkdir(parents=True, exist_ok=True)
    
    checkpoint = {
        "processed_ids": processed_ids,
        "all_results": all_results,
        "results_metrics": [
            {k: v for k, v in m.items() if k != 'page'}  # Page objects nie są serializowalne
            for m in results_metrics
        ]
    }
    
    with open(CHECKPOINT_PATH, "w", encoding="utf-8") as f:
        json.dump(checkpoint, f, ensure_ascii=False, indent=2)

def load_checkpoint() -> dict | None:
    """Wczytuje checkpoint jeśli istnieje."""
    if CHECKPOINT_PATH.exists():
        with open(CHECKPOINT_PATH, "r", encoding="utf-8") as f:
            return json.load(f)
    return None

# %% [markdown]
# # 3. Semantic Polarization

# %% [markdown]
# ### SVM Method

# %%
from helpers.svm_polarization import *

# --- Inicjalizacja ---
polarizer = SVMPolarizer(
    random_seed=42,
    embedding_api=f'{MODEL_IN_USE}'
)
polarizer.set_semantic_features(SEMANTIC_FEATURES)
polarizer.train()

# --- Wczytanie checkpointu ---
checkpoint = load_checkpoint()

if checkpoint:
    processed_ids = set(checkpoint["processed_ids"])
    all_results = checkpoint["all_results"]
    results_metrics = checkpoint["results_metrics"]
    print(f"🔄 Resuming from checkpoint: {len(processed_ids)} pages already processed")
else:
    processed_ids = set()
    all_results = {}
    results_metrics = []
    print("🆕 Starting fresh simulation")

CHECKPOINT_EVERY = 10  # Zapisuj co 10 stron

# --- Pętla z checkpointingiem ---
for i, page_for_analysis in enumerate(pages_all):
    
    page_id = get_page_id(i, page_for_analysis)
    
    # Skip jeśli już przetworzone
    if page_id in processed_ids:
        continue
    
    results = polarizer.calculate_polarization(text=page_for_analysis.page_content)
    all_results[f"tekst_{i}"] = results

    for axis_name, axis_result in results.items():
        feature_name = axis_result['direction_label']
        results_per_feature[feature_name].append(axis_result['direction'])
        result_pages_per_feture[feature_name].append(page_for_analysis)
        results_metrics.append({
            'page': page_for_analysis,
            'axis_name': axis_name,
            'feature_name': feature_name,
            'predicted_value': axis_result['direction_label'],
            'ground_truth_vaccine_stance': page_for_analysis.metadata.get(
                'vaccine_stance_opposite', None
            ),
        })

    processed_ids.add(page_id)
    
    # Checkpoint co N iteracji
    if (i + 1) % CHECKPOINT_EVERY == 0:
        save_checkpoint(list(processed_ids), all_results, results_metrics)
        print(f"💾 Checkpoint saved at page {i+1}/{len(pages_all)}")

# Końcowy checkpoint po zakończeniu
save_checkpoint(list(processed_ids), all_results, results_metrics)
print("✅ END of the simulation")
# Out:
# 🎯 FULL-DIMENSION LINEAR SVM - bez redukcji wymiarowości
# 📡 API embeddingów: gemini
# 📐 Strategia: pełna wymiarowość + linear kernel SVM + optymalizacja regularyzacji
# 📊 Ustawiono 2 kategorii semantycznych
#
# 🔄 Pre-computing embeddingów na pełnej wymiarowości...
#    Unikalne frazy: 40
#    Batch 1/2
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
#    Batch 2/2
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
# ----> generate_embedding_gemini
#    🎯 Wykryto wymiarowość embeddingów: 3072
#    📡 Gemini embeddingi - wymiarowość zmienna
#    ⚡ BARDZO WYSOKOWYMIAROWE - aktywne optymalizacje SVM
# ✅ Pre-computing zakończone w 118.0s
# ✅ Oś pełnowymiarowa: vaccine_stance (vaccine_stance_base ↔ vaccine_stance_opposite)
# 📐 Zidentyfikowano 1 osi dla pełnowymiarowego SVM z linear kernel
# ✅ Kategorie semantyczne ustawione i osie zidentyfikowane
#
# 🏋️ Krok 3: Trenowanie modeli SVM dla każdej osi
#
# 🎯 FULL-DIMENSION LINEAR SVM - TRENOWANIE 1 OSI
# 📐 PEŁNA WYMIAROWOŚĆ EMBEDDINGÓW - bez redukcji
#
# ======================================================================
# 🎯 OSI: vaccine_stance
# ======================================================================
# 📊 Dane: 20 pozytywnych + 20 negatywnych
# 📐 PEŁNE embeddingi: (40, 3072)
#
# 🎯 ANALIZA PEŁNOWYMIAROWA - vaccine_stance
#    📐 PEŁNE wymiary: 40 próbek × 3072 features
#    🎯 BEZ redukcji wymiarowości - wykorzystujemy pełną przestrzeń embeddingów
#    ⚖️  Stosunek features/samples: 76.8
#    🚨 EKSTREMALNE wymiary vs próbki - wymagana bardzo silna regularyzacja
#    📊 Analiza wariancji features:
#      Zero-variance: 0
#      Low-variance (<0.001): 3072
#      High-variance (>1.0): 0
#      Średnia wariancja: 0.000024
#    🎯 Separowalność centroidów:
#      Euclidean distance: 0.3617
#      Cosine similarity: 0.9318
#      Cosine distance: 0.0682
#    ⚠️  Średnia separowalność w przestrzeni cosinusowej
#    💡 REKOMENDACJE PEŁNOWYMIAROWE:
#      • KRYTYCZNE: Użyj bardzo niskich wartości C (< 0.01)
#      • Rozważ dodanie znacznie więcej danych treningowych
#      • Monitoruj overfitting - użyj cross-validation
#      • Użyj regularyzacji jeśli overfitting jest problemem
#      • Rozważ early stopping podczas trenowania
#    🔧 Skalowanie na pełnej wymiarowości...
#    ✅ Skalowanie zakończone: (40, 3072)
#    🎯 OPTYMALIZACJA LINEAR KERNEL SVM - PEŁNA WYMIAROWOŚĆ
#    📐 Optymalizacja na 3072 wymiarach (bez redukcji)
#    🔧 Testowanie 6 wartości C: [1e-05, 0.0001, 0.001, 0.01, 0.02, 0.05]
#    🎯 Używam SVC z kernel='linear' (pełne funkcjonalności + probability)
#    📊 Cross-validation: 5 folds
#      C=  0.000010: 1.0000 (+/- 0.0000)
#      C=  0.000100: 1.0000 (+/- 0.0000)
#      C=  0.001000: 1.0000 (+/- 0.0000)
#      C=  0.010000: 1.0000 (+/- 0.0000)
#      C=  0.020000: 1.0000 (+/- 0.0000)
#      C=  0.050000: 1.0000 (+/- 0.0000)
#
#    🏆 NAJLEPSZA KONFIGURACJA:
#      C = 1e-05
#      CV Score = 1.0000
#      Model type = SVC (linear kernel)
#    📊 Stabilność wyników:
#      Zakres scores: 0.0000
#      Średni score: 1.0000
#    ✅ Wysoka stabilność - wyniki mało zależne od C
#    🎯 Trenowanie finalnego modelu na 3072 wymiarach...
# 1
# 2
# 3
# 4
# 5
#    ✅ Final CV accuracy: 0.6410 (+/- 0.5077)
#    🎯 Support vectors: [20 20] (100.0%)
#    📏 Hiperpłaszczyzna na 3072 wymiarach:
#      Norma wag: 0.012439
#      Bias: 0.009753
#      Margin: 80.395370
#    🔝 Top 5 najważniejszych wymiarów:
#      1. Wymiar 2194: 0.000382
#      2. Wymiar 1618: -0.000382
#      3. Wymiar 2356: 0.000383
#      4. Wymiar 1576: -0.000386
#      5. Wymiar 351: 0.000388
#    ⏱️  Czas trenowania: 0.2s
#    🎯 Finalny CV score: 0.6410
#    🚨 PROBLEMY PEŁNOWYMIAROWE:
#      • EKSTREMALNE wymiary/próbki = 76.8
#      • Wysokie ryzyko overfitting na pełnej wymiarowości
#      💡 DZIAŁANIA:
#        • KRYTYCZNE: Użyj bardzo niskich wartości C (< 0.01)
#        • Rozważ dodanie znacznie więcej danych treningowych
#        • Monitoruj overfitting - użyj cross-validation
#        • Użyj regularyzacji jeśli overfitting jest problemem
#        • Rozważ early stopping podczas trenowania
#
# 🎉 FULL-DIMENSION LINEAR SVM ZAKOŃCZONE!
# ⏱️  Całkowity czas: 0.2s
# 📐 Wszystkie modele trenowane na PEŁNEJ wymiarowości embeddingów
#
# 📐 PODSUMOWANIE PEŁNOWYMIAROWE
# ============================================================
#
# 📐 vaccine_stance:
#    CV Score: 0.6410
#    Wymiary: 3072 (pełne)
#    Margin: 80.395370
#    Ryzyko: extreme
#    C: 1e-05
#
# 📊 STATYSTYKI GLOBALNE:
#    Średnia accuracy: 0.6410
#    Min accuracy: 0.6410
#    Max accuracy: 0.6410
#    Standardowa wymiarowość: 3072
#    Średni margin: 80.395370
#
# 🎯 ROZKŁAD RYZYKA OVERFITTING:
#    extreme: 1 osi
#
# 🚨 GLOBALNE OSTRZEŻENIE:
#    Większość osi ma wysokie ryzyko overfitting
#    Rozważ dodanie więcej danych treningowych
#    Użyj krzyżowej walidacji podczas ewaluacji
# ✅ Wszystkie modele SVM zostały wytrenowane
# 🔍 Analiza pełnowymiarowa: That’s how health journalist Helen Branswell recently described the vaccines that have saved million...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.064)
#      Pełne wymiary: 3072
#      Top wymiary: [2903, 338, 905]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: But once the novel coronavirus was discovered and sequenced in Wuhan, China, everything changed, nea...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.022)
#      Pełne wymiary: 3072
#      Top wymiary: [2483, 2537, 2733]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: “The first time your body sees the spike protein, it activates some immune system cells to begin to ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.008)
#      Pełne wymiary: 3072
#      Top wymiary: [2727, 1859, 718]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Vaccine trials often take years because not only do they need to recruit a lot of participants to be...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.058)
#      Pełne wymiary: 3072
#      Top wymiary: [58, 204, 2733]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Some vaccines, such as the measles or oral polio vaccines, contain a weakened form of the live virus...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.052)
#      Pełne wymiary: 3072
#      Top wymiary: [2125, 2982, 696]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: A vaccine’s efficacy is measured in a controlled clinical trial and is based on how many people who ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.075)
#      Pełne wymiary: 3072
#      Top wymiary: [420, 429, 450]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: One vaccine ingredient that has been studied specifically is thimerosal. Thimerosal is a mercury-bas...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.065)
#      Pełne wymiary: 3072
#      Top wymiary: [303, 2733, 2125]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Can the dramatic increase in autism be ascribed to change in diagnostic practice? Data from the rece...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.052)
#      Pełne wymiary: 3072
#      Top wymiary: [1606, 204, 604]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: When there is very little or no COVID-19 disease in the community, people aren’t so concerned about ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.055)
#      Pełne wymiary: 3072
#      Top wymiary: [2203, 385, 1859]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: When you are vaccinated against COVID-19, you not only protect yourself, but also those around you. ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.075)
#      Pełne wymiary: 3072
#      Top wymiary: [53, 1809, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Accordingly, in addition to its role in protecting them from serious diseases that are still lurking...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.098)
#      Pełne wymiary: 3072
#      Top wymiary: [2543, 2537, 3010]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Recent data suggest COVID-19 vaccines become less effective at preventing infection or severe illnes...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.002)
#      Pełne wymiary: 3072
#      Top wymiary: [2130, 1809, 385]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Viruses are constantly changing, including the virus that causes COVID-19. These changes occur over ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.014)
#      Pełne wymiary: 3072
#      Top wymiary: [2058, 3005, 2130]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Even if you’ve had COVID-19, experts recommend getting vaccinated — and boosted, if you’re eligible....
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.018)
#      Pełne wymiary: 3072
#      Top wymiary: [2847, 1432, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines do not give you a disease. Instead, they teach your body's immune system to recognise and f...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.016)
#      Pełne wymiary: 3072
#      Top wymiary: [411, 2545, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Additionally, there are serious health risks associated with the vaccine that the general public has...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.107)
#      Pełne wymiary: 3072
#      Top wymiary: [306, 285, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Another concern stems from the fact that the COVID-19 vaccine causes our cells to produce the virus ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.096)
#      Pełne wymiary: 3072
#      Top wymiary: [622, 2823, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: But clinical trial results demonstrate the vaccine’s safety in young children. Research published in...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.053)
#      Pełne wymiary: 3072
#      Top wymiary: [2222, 466, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Beyond concerns about side effects, many of the hesitant just don’t have much trust in the vaccines....
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.013)
#      Pełne wymiary: 3072
#      Top wymiary: [2347, 53, 1675]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: For some, the concern is the vaccine itself — and particularly the side effects that can come with i...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.057)
#      Pełne wymiary: 3072
#      Top wymiary: [1719, 470, 1770]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The first reason relates to the view that healthcare is a matter of personal risk, choice, and respo...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.057)
#      Pełne wymiary: 3072
#      Top wymiary: [2553, 696, 428]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The second reason relates to the impact of social exclusion. Exclusion can take many different forms...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.013)
#      Pełne wymiary: 3072
#      Top wymiary: [607, 633, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Some people have had concerns that ASD might be linked to the vaccines children receive, but studies...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.065)
#      Pełne wymiary: 3072
#      Top wymiary: [3005, 2195, 1606]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Based on the extensive review presented, GACVS concluded that no evidence exists of a causal associa...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.074)
#      Pełne wymiary: 3072
#      Top wymiary: [285, 245, 1669]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Opponents say that children’s immune systems can deal with most infections naturally, and that injec...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.028)
#      Pełne wymiary: 3072
#      Top wymiary: [2261, 724, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines can save children’s lives. The American Academy of Pediatrics states that “most childhood v...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.150)
#      Pełne wymiary: 3072
#      Top wymiary: [3010, 3005, 69]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The ingredients in vaccines are safe in the amounts used. Ingredients, such as thimerosal, formaldeh...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.062)
#      Pełne wymiary: 3072
#      Top wymiary: [195, 553, 2125]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Major medical organizations state that vaccines are safe. These organizations include: CDC, Food and...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.110)
#      Pełne wymiary: 3072
#      Top wymiary: [2545, 3005, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines protect future generations. Vaccinated mothers protect their unborn children from viruses t...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.096)
#      Pełne wymiary: 3072
#      Top wymiary: [3010, 2733, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines can cause serious and sometimes fatal side effects. According to the CDC, all vaccines carr...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.050)
#      Pełne wymiary: 3072
#      Top wymiary: [2893, 450, 683]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines contain harmful ingredients. Aluminum is used in some vaccines and excess aluminum in human...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.048)
#      Pełne wymiary: 3072
#      Top wymiary: [204, 3005, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Most diseases that vaccines target are relatively harmless in many cases, thus making vaccines unnec...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.008)
#      Pełne wymiary: 3072
#      Top wymiary: [305, 2023, 2482]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines are considered to be safe. They’re rigorously tested and go through many rounds of study, e...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.042)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 3005, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccination is one of the most successful public health interventions in reducing disease spread, pr...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.069)
#      Pełne wymiary: 3072
#      Top wymiary: [2989, 69, 58]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Some of the pros of mandatory vaccinations at work include:COVID-19 vaccines are effective at helpin...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.059)
#      Pełne wymiary: 3072
#      Top wymiary: [1252, 970, 2537]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: COVID-19 vaccines have been shown to be safe and effective. Rigorous testing has demonstrated the sa...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.049)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 53, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines can have side effects, that is a fact. But they may only be used if they have been extensiv...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.030)
#      Pełne wymiary: 3072
#      Top wymiary: [2545, 450, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: If we take one of these licensed vaccines, we not only protect ourselves. We also protect each other...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.095)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 834, 1675]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: So vaccines are NOT safe by design. Safety by testing ALONE, is an unacceptable strategy for such a ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.025)
#      Pełne wymiary: 3072
#      Top wymiary: [935, 1550, 2545]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Since the Covid-19 vaccines have been released under the emergency use authorization act (EUA) as an...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.109)
#      Pełne wymiary: 3072
#      Top wymiary: [420, 1158, 78]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Research into immunisation has been based on the theory that the benefits of immunisation far outwei...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.019)
#      Pełne wymiary: 3072
#      Top wymiary: [204, 382, 1606]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: In general, skipping vaccines isn't a good idea. This can leave your child vulnerable to potentially...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.051)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 3005, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Any vaccine can cause side effects. Usually, these side effects are minor — a low-grade fever, fussi...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.014)
#      Pełne wymiary: 3072
#      Top wymiary: [411, 450, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The official narrative is collapsing. The winter of 2022 was supposed to be a “winter of death” for ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.092)
#      Pełne wymiary: 3072
#      Top wymiary: [428, 1630, 834]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Vaccinated individuals have accounted for 73 percent of all covid-19 cases in England over the past ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.113)
#      Pełne wymiary: 3072
#      Top wymiary: [1302, 834, 2141]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: As The Epoch Times and other media outlets reported yesterday, a shocking new study conducted at Lun...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.133)
#      Pełne wymiary: 3072
#      Top wymiary: [1080, 2865, 683]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: The genetic material delivered by mRNA vaccines never enters the nucleus of your cells, which is whe...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.124)
#      Pełne wymiary: 3072
#      Top wymiary: [718, 204, 429]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: New York-based physician Dr. Vladimir “Zev” Zelenko warned that anyone with immunodeficiency can die...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.097)
#      Pełne wymiary: 3072
#      Top wymiary: [1166, 2892, 2983]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Physician and author Dr. Jane Ruby exposed the gross incompetence of people who administer the Wuhan...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.055)
#      Pełne wymiary: 3072
#      Top wymiary: [683, 420, 204]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Ruby noted that most of the people giving the COVID injections have no training at all. She also cit...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.049)
#      Pełne wymiary: 3072
#      Top wymiary: [219, 2061, 420]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: For now, those who believe in the overwhelmingly debunked theories of vaccines remain in the minorit...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.078)
#      Pełne wymiary: 3072
#      Top wymiary: [12, 2707, 52]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: It is true that the production of all three of the leading candidates – the newly-approved Pfizer/Bi...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.012)
#      Pełne wymiary: 3072
#      Top wymiary: [730, 450, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Thalidomide is a drug that was marketed as a treatment for morning sickness in pregnant women in the...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.040)
#      Pełne wymiary: 3072
#      Top wymiary: [2492, 450, 58]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: There are unfortunate and disturbing reports that childhood vaccine administration is being disrupte...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.068)
#      Pełne wymiary: 3072
#      Top wymiary: [1662, 2058, 2221]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Yes. The two mRNA vaccines, Pfizer and Moderna, authorized by the U.S. Food and Drug Administration ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.057)
#      Pełne wymiary: 3072
#      Top wymiary: [53, 2759, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: COVID-19 vaccines have proven to be safe, effective and life-saving. Like all vaccines, they do not ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.095)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 1809, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: A COVID-19 vaccine might: Protect you from getting COVID-19, Prevent you from becoming seriously ill...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.031)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 3005, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Proponents say that vaccination is safe and one of the greatest health developments of the 20th cent...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.146)
#      Pełne wymiary: 3072
#      Top wymiary: [724, 53, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Parental refusal of vaccines is a growing a concern for the increased occurrence of vaccine preventa...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.050)
#      Pełne wymiary: 3072
#      Top wymiary: [69, 2537, 2466]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: I just finished watching the “stop the mandate” march in DC. There were lots of people that have bee...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.060)
#      Pełne wymiary: 3072
#      Top wymiary: [0, 2877, 824]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Proponents of vaccine mandates typically claim that everyone who can be vaccinated has a moral or et...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.005)
#      Pełne wymiary: 3072
#      Top wymiary: [3066, 273, 2061]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Childhood vaccines protect children from a variety of serious or potentially fatal diseases, includi...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.100)
#      Pełne wymiary: 3072
#      Top wymiary: [1225, 53, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Any vaccine can cause side effects. Usually, these side effects are minor — a low-grade fever, fussi...
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.014)
#      Pełne wymiary: 3072
#      Top wymiary: [411, 450, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: I feel that a vaccine is a huge intervention in my body. Everyone should make this decision for them...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.051)
#      Pełne wymiary: 3072
#      Top wymiary: [1420, 428, 2877]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Some people don’t get flu vaccines for themselves or for their children. There are several reasons f...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.012)
#      Pełne wymiary: 3072
#      Top wymiary: [3005, 696, 53]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The advantages of immunisation are obvious - they stop individuals becoming ill. If enough people ar...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.109)
#      Pełne wymiary: 3072
#      Top wymiary: [1842, 3005, 1859]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: In recent years there has been much controversy surrounding the MMR vaccine. Some people used to thi...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.052)
#      Pełne wymiary: 3072
#      Top wymiary: [2733, 2758, 1986]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: COVID-19 vaccines are safe, and getting vaccinated will help protect you against developing severe C...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.001)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 53, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Studies show that vaccines are necessary for children to fight against diseases. It has various bene...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.117)
#      Pełne wymiary: 3072
#      Top wymiary: [53, 63, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The World Health Organization (WHO) not only advises that vaccines save lives, but also reduce trans...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.073)
#      Pełne wymiary: 3072
#      Top wymiary: [83, 2607, 1859]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The Australian government says vaccination is the most effective way to protect against infectious d...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.088)
#      Pełne wymiary: 3072
#      Top wymiary: [225, 385, 1652]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: A new study has also found a reduction in transmission rates even after the first dose. Those who te...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.052)
#      Pełne wymiary: 3072
#      Top wymiary: [83, 204, 718]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Because of advances in medical science, your child can be protected against more diseases than ever ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.139)
#      Pełne wymiary: 3072
#      Top wymiary: [53, 2847, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Vaccines are only given to children after a long and careful review by scientists, doctors, and heal...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.060)
#      Pełne wymiary: 3072
#      Top wymiary: [2537, 450, 696]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Children in the U.S. still get still get vaccine-preventable diseases. In fact, we have seen resurge...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.114)
#      Pełne wymiary: 3072
#      Top wymiary: [1280, 1809, 2847]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: A child with a vaccine-preventable disease can be denied attendance at schools or daycare facilities...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.055)
#      Pełne wymiary: 3072
#      Top wymiary: [204, 309, 637]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Vaccines have reduced and, in some cases, eliminated many diseases that killed or severely disabled ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.119)
#      Pełne wymiary: 3072
#      Top wymiary: [1809, 3005, 3010]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: WHO's Strategic Advisory Group of Experts (SAGE) has concluded that the Pfizer vaccine is safe to be...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.102)
#      Pełne wymiary: 3072
#      Top wymiary: [3063, 2152, 204]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Covid-19 is a coronavirus (like a cold). ALL coronaviruses can be prevented and treated through more...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.013)
#      Pełne wymiary: 3072
#      Top wymiary: [2098, 2285, 137]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: After 2 years of Covid ravaging America, less than 1 in 7 people have statistically been known to co...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.041)
#      Pełne wymiary: 3072
#      Top wymiary: [1452, 2755, 603]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: According to the CDC’s own numbers, Covid-19 has a 99.74% survival rate, IF you even get the virus. ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.044)
#      Pełne wymiary: 3072
#      Top wymiary: [491, 39, 683]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Since the vaccinated can still get the virus, if the vaccines work then why isn’t the survival rate ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.047)
#      Pełne wymiary: 3072
#      Top wymiary: [683, 1329, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: These vaccines, by definition, are not vaccines, but medical treatments. It is against the law for a...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.031)
#      Pełne wymiary: 3072
#      Top wymiary: [2759, 2492, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Why are these numbers immediately discounted as being unconnected, with no room for discussion? If t...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.063)
#      Pełne wymiary: 3072
#      Top wymiary: [2883, 2347, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The three manufacturers, Pfizer, Moderna, And Johnson & Johnson have said don’t take their vaccines ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.013)
#      Pełne wymiary: 3072
#      Top wymiary: [2466, 1252, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Most patients, however, are unaware that among relevant scientific experts such a view is not so rea...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.068)
#      Pełne wymiary: 3072
#      Top wymiary: [2058, 137, 3011]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Perhaps the most pertinent finding is that, due to the discovery of a widespread memory-type antibod...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.113)
#      Pełne wymiary: 3072
#      Top wymiary: [1606, 1809, 450]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: The implications for doctors and patients are that: Vaccination against COVID-19 is unnecessary. Pop...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.094)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 3011, 309]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: But what about the second and third waves of “cases”, including from Delta and other variants, aroun...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.074)
#      Pełne wymiary: 3072
#      Top wymiary: [420, 450, 462]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: While the now clearly established widespread cross-immunity against SARS-CoV-2 implies that most of ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.148)
#      Pełne wymiary: 3072
#      Top wymiary: [2636, 1080, 429]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: This immune reaction will in principle resemble that to an infection with the corresponding wild-typ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.117)
#      Pełne wymiary: 3072
#      Top wymiary: [696, 429, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 2.4.2. Delivering the Spike Protein into the Bloodstream A dire danger of COVID-19 vaccines is that ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.106)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 2222, 420]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: A dire danger of COVID-19 vaccines is that spike proteins produced by myriad endothelial cells, i.e....
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.122)
#      Pełne wymiary: 3072
#      Top wymiary: [2222, 204, 420]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 2.4.3. Attacking the Vessel Walls: Clotting and Leaky Vessels While all vaccines seek to stimulate a...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.132)
#      Pełne wymiary: 3072
#      Top wymiary: [1679, 1080, 2456]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 2.4.3.2. Antibodies Before the new discoveries of 2021, scientists’ concerns about clotting and blee...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.114)
#      Pełne wymiary: 3072
#      Top wymiary: [1080, 2500, 420]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: 2.4.3.3. Complement Recent findings indicate that complement activation is a serious concern with re...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.137)
#      Pełne wymiary: 3072
#      Top wymiary: [564, 3011, 450]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 2.4.3.4. Leaky Vessels—The Promise of Booster Shots Given that booster shots repeatedly boost the im...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.151)
#      Pełne wymiary: 3072
#      Top wymiary: [1080, 935, 834]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 2.4.4. Enhancing the Severity of Wild Coronavirus Infection Finally, as with the Dengue virus and se...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.109)
#      Pełne wymiary: 3072
#      Top wymiary: [521, 564, 450]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: Implications for Doctors and Patients     Although vaccine manufacturers and regulators are aware of...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.090)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 3011, 2983]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: My friend and tennis partner, a mid fifties very fit doctor, turned blue all over with broken capill...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.106)
#      Pełne wymiary: 3072
#      Top wymiary: [450, 420, 2187]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: He added that some vaccine recipients suffered from serious adverse reactions, which often were foll...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.149)
#      Pełne wymiary: 3072
#      Top wymiary: [1550, 420, 2012]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: The cardiologist warned that young people should steer clear of the vaccines as the jabs can cause s...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.090)
#      Pełne wymiary: 3072
#      Top wymiary: [639, 1809, 522]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: CLS is an extremely rare, serious condition that causes fluid to leak from small blood vessels (capi...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.060)
#      Pełne wymiary: 3072
#      Top wymiary: [502, 2585, 2726]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: “We will have a safety profile for only a certain number of months, so if there is a long-term effec...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_opposite (siła: 0.013)
#      Pełne wymiary: 3072
#      Top wymiary: [204, 2222, 730]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Hundreds of Nebraska physicians and health care providers have signed a statement of support for vac...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.136)
#      Pełne wymiary: 3072
#      Top wymiary: [2644, 3011, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: “We're seeing a trend; kids who are not yet vaccinated are getting COVID-19 and becoming severely il...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.107)
#      Pełne wymiary: 3072
#      Top wymiary: [696, 2537, 204]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Sharon Stoolman, M.D., a pediatric hospitalist at Children’s, said she frequently hears a few miscon...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.061)
#      Pełne wymiary: 3072
#      Top wymiary: [696, 2644, 3011]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Health care providers are the absolute best source for health information  “When folks are hesitant ...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.107)
#      Pełne wymiary: 3072
#      Top wymiary: [696, 2483, 2537]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: “In addition to masking, washing your hands and social distancing, vaccination helps keep families s...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.117)
#      Pełne wymiary: 3072
#      Top wymiary: [3048, 1606, 2537]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: Pharmaceutical industry expert Professor Frank Lichtenberg estimates that the value of a vaccine cou...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.042)
#      Pełne wymiary: 3072
#      Top wymiary: [2548, 2084, 2219]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: What is currently unknown is the ultimate impact of those burdens on future economic activity, which...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.016)
#      Pełne wymiary: 3072
#      Top wymiary: [704, 1719, 1675]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: “Vaccination is as important for adults as it is for children, and yet many adults are not optimally...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.087)
#      Pełne wymiary: 3072
#      Top wymiary: [3010, 2226, 69]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 1. You may no longer be protected. You may have received a vaccine as a child. But some vaccines req...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.016)
#      Pełne wymiary: 3072
#      Top wymiary: [1809, 39, 2537]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa:  2. Getting vaccines helps protect your kids -- especially babies too young for vaccines.Whooping co...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.134)
#      Pełne wymiary: 3072
#      Top wymiary: [53, 1697, 2537]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 4. You may need them when you travel. Headed to the developing world? You may run into illnesses you...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.091)
#      Pełne wymiary: 3072
#      Top wymiary: [3010, 39, 2226]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 5. Everyone needs a flu vaccine, every year. The CDC recommends that everyone 6 months of age and ol...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.073)
#      Pełne wymiary: 3072
#      Top wymiary: [385, 53, 3005]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 6. Your kids have set an example. Most children don’t have a choice about getting shots. But why sho...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.115)
#      Pełne wymiary: 3072
#      Top wymiary: [411, 2226, 1432]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 7. You didn’t get fully vaccinated as a child. Not everyone was, or is, fully vaccinated as a child....
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.012)
#      Pełne wymiary: 3072
#      Top wymiary: [1675, 411, 1792]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: 9. You’re going back to college. The downturn has forced many adults back to school. But many colleg...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.040)
#      Pełne wymiary: 3072
#      Top wymiary: [2537, 1432, 2226]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 10. You work in the health care profession. Health care providers are exposed to all sorts of potent...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.064)
#      Pełne wymiary: 3072
#      Top wymiary: [249, 2537, 2226]
#      ⚠️  Ostrzeżenia: 4
# 🔍 Analiza pełnowymiarowa: 11. You’re sexually active with a number of partners. The hepatitis B vaccine is highly recommended....
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.009)
#      Pełne wymiary: 3072
#      Top wymiary: [309, 420, 718]
#      ⚠️  Ostrzeżenia: 3
# 🔍 Analiza pełnowymiarowa: 12. You have asthma, heart, lung disease, diabetes, or other chronic disease. Or you smoke cigarette...
# ----> generate_embedding_gemini
#      Skalowanie na 3072 wymiarach
#   📐 vaccine_stance: vaccine_stance_base (siła: 0.019)
#      Pełne wymiary: 3072
#      Top wymiary: [1432, 1809, 718]
#      ⚠️  Ostrzeżenia: 3
# ✅ Zapisano: ./results_ZDROWOTNE_baseline_2_ONE_gemini/results_ZDROWOTNE_baseline_2_ONE_gemini_svm_plot.pdf
# ✅ Zapisano: ./results_ZDROWOTNE_baseline_2_ONE_gemini/results_ZDROWOTNE_baseline_2_ONE_gemini_svm_plot.png
# ✅ Konic badania

# %% [markdown]
# # 4. Generating reports -  confusion matrix

# %%
from re import X
from huggingface_hub import Padding
from matplotlib.patches import Rectangle, Patch
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np

def generate_summary_report(results_data):
    """
    Generuje zbiorczy raport z wynikami dla wszystkich osi,
    z ulepszoną wizualizacją i profesjonalnym wyglądem.
    
    :param results_data: Lista słowników z wynikami
    """
    from collections import Counter
    
    # Ustaw profesjonalny styl mtplotlib
    plt.rcParams.update({
        'font.size': 11,
        'axes.labelsize': 12,
        'axes.titlesize': 14,
        'xtick.labelsize': 14,
        'ytick.labelsize': 14,
        'legend.fontsize': 10,
        'figure.titlesize': 16,
        'axes.grid': True,
        'grid.alpha': 0.3,
        'axes.axisbelow': True,
        'axes.edgecolor': '#CCCCCC',
        'axes.linewidth': 0.8,
        'figure.facecolor': 'white',
        'axes.facecolor': '#fafffa'
    })
    
    # Znajdź wszystkie unikalne osie
    axes = sorted(list(set(item['axis_name'] for item in results_data)))
    
    # Przygotuj słownik do zbierania statystyk
    stats = {axis: {'correct': 0, 'total': 0, 'predictions': Counter(), 'true_labels': Counter()} for axis in axes}
    
    # Zlicz poprawne predykcje dla każdej osi
    for item in results_data:
        axis = item['axis_name']
        predicted = item['feature_name']
        
        if "balanced" in predicted:
            continue
            
        ground_truth = None
        true_label = None

        if 'vaccine_stance' in axis:
            ground_truth = item.get('ground_truth_vaccine_stance')
            if ground_truth is True:
                true_label = 'vaccine_stance_opposite'
            elif ground_truth is False:
                true_label = 'vaccine_stance_base'
            else:
                continue
        else:
            continue
        
        stats[axis]['predictions'][predicted] += 1
        stats[axis]['true_labels'][true_label] += 1
        stats[axis]['total'] += 1
        if predicted == true_label:
            stats[axis]['correct'] += 1
    
    # Wyświetl zbiorczy raport
    print("\n=== ZBIORCZY RAPORT ===")
    print(f"Łączna liczba próbek: {sum(stats[axis]['total'] for axis in axes)}")
    print("\nWyniki dla poszczególnych osi:")
    
    # Przygotuj dane do wykresu
    axis_names = []
    accuracies = []
    
    for axis in axes:
        correct = stats[axis]['correct']
        total = stats[axis]['total']
        
        if total == 0:
            print(f"\n{axis}: Brak danych")
            continue
            
        accuracy = correct / total
        axis_names.append(axis)
        accuracies.append(accuracy)
        
        print(f"\n{axis}:")
        print(f"  Liczba próbek: {total}")
        print(f"  Poprawnych predykcji: {correct}")
        print(f"  Dokładność: {accuracy:.1%} ({correct}/{total})")
        
        print("\n  Rozkład przewidywań:")
        for label, count in sorted(stats[axis]['predictions'].items()):
            percentage = count / sum(stats[axis]['predictions'].values())
            print(f"    {label}: {count} ({percentage:.2%})")
        
        print("\n  Rozkład rzeczywistych etykiet:")
        for label, count in sorted(stats[axis]['true_labels'].items()):
            percentage = count / sum(stats[axis]['true_labels'].values())
            print(f"    {label}: {count} ({percentage:.2%})")
    
    if not axis_names:
        print("\nBrak danych dla wszystkich osi.")
        return
    
    # Łączna dokładność
    total_correct = sum(stats[axis]['correct'] for axis in axes)
    total_samples = sum(stats[axis]['total'] for axis in axes)
    total_accuracy = total_correct / total_samples if total_samples > 0 else 0
    
    # WYKRES 1: Poziomy wykres słupkowy dokładności
    fig_height = 6
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Utwórz gradient kolorów dla słupków
    colors = plt.cm.summer_r(np.linspace(0.2, 0.9, len(axis_names)))
    
    y_pos = np.arange(len(axis_names)*0.75)
    bar_height = 0.5
    bars = ax.barh(y_pos, accuracies, height=bar_height, 
                   color=colors, edgecolor='white', linewidth=1.5)
    

    
    # Dodaj gradient/cienie do słupków
    for i, (bar, accuracy) in enumerate(zip(bars, accuracies)):
        # Dodaj subtelny gradient
        bar.set_facecolor(colors[i])
        
        # Dodaj ramkę z zaokrąglonymi rogami (symulacja)
        bar.set_edgecolor('white')
        bar.set_linewidth(2)

    
    from matplotlib.patheffects import withSimplePatchShadow
    for bar in bars:
        bar.set_path_effects([withSimplePatchShadow(offset=(2, -2), 
                                                shadow_rgbFace='grey', 
                                                alpha=0.3)])


    # Profesjonalne etykiety
    ax.set_xlabel('Dokładność klasyfikacji', fontsize=18, fontweight='bold', labelpad=30,fontname='Arial')
    ax.set_ylabel('Kryteria polaryzacyjne', fontsize=18 ,fontweight='bold', labelpad=30, fontname='Arial')
    #ax.set_title('Analiza dokładności klasyfikacji\ndla przyjętych kryteriów polaryzacyjnych', 
     #           fontsize=16, fontweight='bold', color='#2C3E50', pad=20)
    
    # Ustaw zakresy
    ax.set_xlim(0, 1.1)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(axis_names, fontsize=16,fontname='Arial')

    
    # Dodaj eleganckie wartości obok słupków
    for i, (bar, accuracy) in enumerate(zip(bars, accuracies)):
        width = bar.get_width()
        ax.text(width + 0.02, bar.get_y() + bar.get_height()/2.,
                f'{accuracy:.1%}', 
                ha='left', va='center', fontsize=16,fontname='Arial', fontweight='bold',
                color='#2C3E50',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='white', 
                         edgecolor='#BDC3C7', alpha=0.9))
    
    # Dodaj elegancką linię średniej
    ax.axvline(x=total_accuracy, color='#E74C3C', linestyle='--', linewidth=2.5, alpha=0.8)
    ax.text(total_accuracy + 0.02, len(axis_names) - 0.5, 
            f'Wartość uśrednia: {total_accuracy:.1%}',
            ha='center', va='center', fontsize=14, fontweight='bold',
            color='#E74C3C',
            bbox=dict(boxstyle="round,pad=0.4", facecolor='#FCF3CF', 
                     edgecolor='#E74C3C', alpha=0.9))
    
    # Ulepszona siatka
    ax.grid(axis='x', linestyle='-', alpha=0.3, color='#BDC3C7')
    ax.set_axisbelow(True)
    
    # Usuń niepotrzebne ramki
    ax.spines['top'].set_visible(True)
    ax.spines['right'].set_visible(True)
    ax.spines['left'].set_color('#BDC3C7')
    ax.spines['bottom'].set_color('#BDC3C7')
    
    plt.tight_layout()
    plt.savefig(f'{NAME_OF_SIMULATION}_accurency.png', dpi=400, bbox_inches='tight')

    plt.show()
    
    # WYKRES 2: Ulepszone wykresy porównawcze dla każdej osi
    for axis_idx, axis in enumerate(axes):
        if stats[axis]['total'] == 0:
            continue
        
        all_labels = set()
        all_labels.update(stats[axis]['predictions'].keys())
        all_labels.update(stats[axis]['true_labels'].keys())
        sorted_labels = sorted(list(all_labels))
        
        pred_counts = [stats[axis]['predictions'].get(label, 0) for label in sorted_labels]
        true_counts = [stats[axis]['true_labels'].get(label, 0) for label in sorted_labels]
        
        # Dynamiczny rozmiar figury
        fig_height = 10
        fig, ax = plt.subplots(figsize=(18, fig_height))
        
        y = np.arange(len(sorted_labels))
        height = 0.25
        
        # Eleganckie kolory
        pred_color = '#3498DB'  # Niebieski
        true_color = '#27AE60'  # Zielony
        
        # Utwórz słupki
        bars1 = ax.barh(y - height/2, pred_counts, height, label='Liczba predykcji', 
                        color=pred_color, edgecolor='white', linewidth=1.5)

        bars2 = ax.barh(y + height/2, true_counts, height, label='Liczba etykiet rzeczywistych', 
                        color=true_color, edgecolor='white', linewidth=1.5)


        for pred, true, pos in zip(pred_counts, true_counts, y):
            diff = pred - true
            ax.text(max(pred, true) + 0.5, pos, f'{diff:+.0f}', va='center', fontsize=18,
                    color='darkred' if diff < 0 else 'darkgreen',fontname='Arial')


        # Dodaj eleganckie różnice
        for i in range(len(sorted_labels)):
            diff = pred_counts[i] - true_counts[i]
            if diff != 0:
                max_width = max(pred_counts[i], true_counts[i])
                
                # Kolor różnicy na podstawie wielkości
                if diff > 0:
                    diff_color = 'red'  # Czerwony dla nadmiaru
                else:
                    diff_color = 'blue'  # niebieski dla niedoboru
                
                ax.annotate(
                    f"{'+' if diff > 0 else ''}{diff}",
                    xy=(max_width + 1, y[i]),
                    ha='left', va='center',
                    fontsize=18, color=diff_color,
                    bbox=dict(boxstyle="round,pad=0.4", 
                             facecolor='white', edgecolor=diff_color, 
                             alpha=0.9, linewidth=1.5)
                )
        ax.tick_params(axis='both', labelsize=18)

        # Profesjonalne etykiety
        ax.set_ylabel('Jakości różnicujące', fontsize=22, labelpad=30, fontweight='bold', fontname='Arial')
        ax.set_xlabel('Liczba próbek', fontsize=22, labelpad=30, fontweight='bold', fontname='Arial')
       # ax.set_title(f'Analiza porównawcza przewidywań do rzeczywistych etykiet,\n kryterium polaryzacyjne: {axis}', 
        #            fontsize=15,  fontweight='bold', pad=25)
        X_AXES_LIM= 80
        ax.set_xlim(0, X_AXES_LIM)

        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

        
        for bars, color in [(bars1, pred_color), (bars2, true_color)]:
            for bar in bars:
                width = bar.get_width()
                if width > 0:
                    ax.text(width + 0.5, bar.get_y() + bar.get_height()/2.,
                           f'{int(width)}', ha='left', va='center',
                           fontsize=16, fontweight='bold', color=color)
                    

        from matplotlib.patheffects import withSimplePatchShadow
        for bar in bars:
            bar.set_path_effects([withSimplePatchShadow(offset=(2, -2), 
                                                    shadow_rgbFace='grey', 
                                                    alpha=0.3)])
        
        # Ustaw etykiety osi Y
        ax.set_yticks(y)
        
        # Skróć długie nazwy etykiet dla lepszej czytelności
        short_labels = []
        for label in sorted_labels:
            if len(label) > 25:
                # Inteligentne skracanie przy zachowaniu kluczowych słów
                parts = label.split('_')
                if len(parts) >= 2:
                    short_label = label
                else:
                    short_label = label
            else:
                short_label = label
            short_labels.append(short_label)
        
        ax.set_yticklabels(short_labels, fontsize=18, rotation= 0,va='center')
        
        # Dodaj kolorowe tło dla kategorii
        for i, label in enumerate(sorted_labels):
            is_anti = any(term in label.lower() for term in ['opposite'])
            
            if is_anti:
                bg_color = '#FADBD8'  # Jasny czerwony
                pattern_color = '#E74C3C'
                hatch_pattern = '///'
            else:
                bg_color = '#D5F4E6'  # Jasny zielony
                pattern_color = '#27AE60'
                hatch_pattern = '...'
            
            # Subtelne tło
            ax.axhspan(i - 0.4, i + 0.4, alpha=0.5, color=bg_color, zorder=0)
            
            # Subtelny wzór
            rect = Rectangle((0, i - 0.4), ax.get_xlim()[1] if ax.get_xlim()[1] > 0 else 50, 0.8,
                           fill=False, hatch=hatch_pattern, alpha=0.5,
                           edgecolor=pattern_color, linewidth=0, zorder=-1)
            ax.add_patch(rect)
        
        # Elegancka legenda
        legend1 = ax.legend(loc='lower right', frameon=True, fancybox=True, 
                           shadow=False, edgecolor='#BDC3C7',  fontsize=16)
        legend1.get_frame().set_facecolor('#FAFAFA')
        
        # Dodaj drugą legendę dla kategorii
        antivax_patch = Patch(facecolor='#FADBD8', alpha=0.6, edgecolor='#E74C3C',
                             hatch='///', linewidth=3, label='Teksty antyszczepionkowe')
        provax_patch = Patch(facecolor='#D5F4E6', alpha=0.6, edgecolor='#27AE60',
                            hatch='...', linewidth=3, label='Teksty proszczepieniowe')
        
        legend2 = ax.legend(handles=[antivax_patch, provax_patch], 
                           loc='upper right', frameon=True, fancybox=True, fontsize=16,
                           shadow=False, edgecolor='#BDC3C7')
        legend2.get_frame().set_facecolor('#FAFAFA')
        ax.add_artist(legend1)
        
        # Profesjonalna siatka
        ax.grid(axis='x', linestyle='-', alpha=0.3, color='#BDC3C7')
        ax.set_axisbelow(True)
    
        
        # Usuń niepotrzebne ramki
        for spine in ['top', 'right']:
            ax.spines[spine].set_visible(True)
        for spine in ['left', 'bottom']:
            ax.spines[spine].set_color('#BDC3C7')
            ax.spines[spine].set_linewidth(0.8)
        
        # Dodaj statystyki w eleganckim oknie
        total_pred = sum(pred_counts)
        total_true = sum(true_counts)
        accuracy = sum(min(p, t) for p, t in zip(pred_counts, true_counts)) / total_true if total_true > 0 else 0
        
        
        plt.tight_layout(rect=[0, 0, 0.85, 0.95])

        plt.savefig(f'./{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}_com_{axis}.png', dpi=400, bbox_inches='tight')

        plt.show()
    
    # Resetuj styl matplotlib na koniec
    plt.rcdefaults()


def generate_confusion_matrix(results_data, axis_name=None):
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
    from collections import Counter
    
    # Jeśli podano konkretną oś, filtrujemy wyniki tylko dla tej osi
    if axis_name:
        filtered_results = [item for item in results_data if item['axis_name'] == axis_name]

        axes_to_analyze = [axis_name]
    else:
        filtered_results = results_data
        # Znajdź wszystkie unikalne osie
        axes_to_analyze = list(set(item['axis_name'] for item in results_data))
    
    # Przygotuj słownik do przechowywania wyników dla każdej osi
    results = {}
    
    for current_axis in axes_to_analyze:
        # Filtruj wyniki dla bieżącej osi
        axis_results = [item for item in filtered_results if item['axis_name'] == current_axis]
        
        if not axis_results:
            print(f"Brak danych dla osi {current_axis}")
            continue
        
        # Określ typ osi na podstawie jej nazwy
        axis_type = None
        if 'vaccine_stance' in current_axis:
            axis_type = 'vaccine_stance'

        
        if not axis_type:
            print(f"Nieobsługiwany typ osi: {current_axis}")
            continue
        
        # Przygotuj listy predykcji i rzeczywistych etykiet
        predictions = []
        true_labels = []
        
        for item in axis_results:
            # Dodaj predykcję - nazwa cechy w obecnym formacie
            predicted_label = item['feature_name']
            
            # Jeśli predicted zawiera "balanced", pomijamy ten przypadek
            if "balanced" in predicted_label:
                continue
                
            # Określ wartość rzeczywistą (ground_truth) na podstawie typu osi
            ground_truth_value = None
            if axis_type == 'vaccine_stance':
                ground_truth_value = item.get('ground_truth_vaccine_stance')

                
            # Jeśli ground_truth_value jest None (balanced), pomijamy ten przypadek
            if ground_truth_value is None:
                continue
                

            if ground_truth_value is True:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_opposite'

            elif ground_truth_value is False:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_base'

            else:
                continue  # Ten przypadek nie powinien wystąpić po powyższym sprawdzeniu
            
            # Dodaj do list
            predictions.append(predicted_label)
            true_labels.append(true_label)
        
        
        # Dynamicznie wykryj wszystkie unikalne klasy (etykiety)
        unique_predictions = set(predictions)
        unique_true_labels = set(true_labels)
        classes = sorted(list(unique_predictions.union(unique_true_labels)))
        
        # Oblicz macierz pomyłek
        cm = confusion_matrix(true_labels, predictions, labels=classes)
        
        # Oblicz znormalizowaną macierz pomyłek
        row_sums = cm.sum(axis=1)
        cm_normalized = np.zeros_like(cm, dtype=float)
        
        for i in range(len(row_sums)):
            if row_sums[i] > 0:
                cm_normalized[i] = cm[i] / row_sums[i]
        
        # Oblicz metryki
        accuracy = accuracy_score(true_labels, predictions)
        
        try:
            precision = precision_score(true_labels, predictions, average='macro', labels=classes, zero_division=0)
            recall = recall_score(true_labels, predictions, average='macro', labels=classes, zero_division=0)
            f1 = f1_score(true_labels, predictions, average='macro', labels=classes, zero_division=0)
        except Exception as e:
            print(f"Błąd podczas obliczania metryk dla osi {current_axis}: {e}")
            precision = recall = f1 = 0
        
        # Zapisz wyniki
        results[current_axis] = {
            'confusion_matrix': cm,
            'normalized_confusion_matrix': cm_normalized,
            'classes': classes,
            'predictions': predictions,
            'true_labels': true_labels,
            'metrics': {
                'accuracy': accuracy,
                'precision': precision,
                'recall': recall,
                'f1': f1
            }
        }
        
        # Wizualizacja
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
 
        # Macierz bez normalizacji
        im1 = ax1.imshow(cm, interpolation='nearest', cmap=plt.cm.BuGn)
        fig.suptitle(f'Kryterium polaryzacyjne: {current_axis}', fontsize=24, fontweight='bold', fontname='Arial')
       # Colorbar i ustawienie jego czcionki
        cbar1 = plt.colorbar(im1, ax=ax1)  # <== tu przypisujemy cbar
        cbar1.ax.tick_params(labelsize=16)  # zmiana rozmiaru ticków

     
        # Etykiety
        tick_marks = np.arange(len(classes))
        ax1.set_xticks(tick_marks)

        
        # new_classes = change_spaces(classes)
        ax1.set_xticklabels(classes, rotation=0, ha='center',  fontsize=15,fontname='Arial')
        ax1.set_yticks(tick_marks)
        ax1.set_yticklabels(classes, rotation=90,  va='center',  fontsize=15, fontname='Arial')
        
        # Wartości 
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax1.text(j, i, format(cm[i, j], 'd'),
                        horizontalalignment="center", fontsize=18,
                        color="white" if cm[i, j] > thresh else "black")
        
        ax1.set_ylabel('Prawdziwa etykieta', labelpad=30,  fontsize=22, fontweight='bold',fontname='Arial')
        ax1.set_xlabel('Przewidywana etykieta', labelpad=30,  fontsize=22, fontweight='bold',fontname='Arial')
        
        # Macierz znormalizowana
        im2 = ax2.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.BuGn)
        # ax2.set_title(f'Kryterium polaryzacyjne: {current_axis}',  fontsize=18)
        cbar2 = plt.colorbar(im2, ax=ax2)
        cbar2.ax.tick_params(labelsize=16)  # zmiana rozmiaru ticków

        # Etykiety
        ax2.set_xticks(tick_marks)
        ax2.set_xticklabels(classes, rotation=0, ha='center',  fontsize=15, fontname='Arial')
        ax2.set_yticks(tick_marks)
        ax2.set_yticklabels(classes, rotation=90, va='center',  fontsize=15, fontname='Arial')
        
        # Wartości
        thresh = 0.5
        for i in range(cm_normalized.shape[0]):
            for j in range(cm_normalized.shape[1]):
                ax2.text(j, i, f"{cm_normalized[i, j]:.1%}",  # Format procentowy z jednym miejscem po przecinku
                horizontalalignment="center", fontsize=18,
                color="white" if cm_normalized[i, j] > thresh else "black")
        
        ax2.set_ylabel('Prawdziwa etykieta', labelpad=30 , fontsize=22, fontweight='bold', fontname='Arial' )
        ax2.set_xlabel('Przewidywana etykieta', labelpad=30 ,  fontsize=22, fontweight='bold', fontname='Arial')
        
        plt.tight_layout()
        plt.subplots_adjust(top=0.9)
       # plt.savefig(f'./{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}_cf_mx_{current_axis}.png', dpi=400, bbox_inches='tight')

        plt.show()
        
        # Wyświetl metryki
        print(f"\nMetryki dla osi {current_axis}:")
        print(f"Liczba próbek: {len(true_labels)}")
        print(f"Dokładność: {accuracy:.1%}")
        print(f"Precyzja: {precision:.1%}")
        print(f"Czułość: {recall:.1%}")
        print(f"Wynik F1  {f1:.1%}")


import ast

# Generuj macierze pomyłek dla wszystkich osi
results = generate_confusion_matrix(results_metrics)

# Generuj zbiorczy raport
generate_summary_report(results_metrics)
# Out:
# Metryki dla osi vaccine_stance:
# Liczba próbek: 122
# Dokładność: 90.2%
# Precyzja: 90.1%
# Czułość: 89.7%
# Wynik F1  89.9%
#
# === ZBIORCZY RAPORT ===
# Łączna liczba próbek: 122
#
# Wyniki dla poszczególnych osi:
#
# vaccine_stance:
#   Liczba próbek: 122
#   Poprawnych predykcji: 110
#   Dokładność: 90.2% (110/122)
#
#   Rozkład przewidywań:
#     vaccine_stance_base: 72 (59.02%)
#     vaccine_stance_opposite: 50 (40.98%)
#
#   Rozkład rzeczywistych etykiet:
#     vaccine_stance_base: 70 (57.38%)
#     vaccine_stance_opposite: 52 (42.62%)

# %% [markdown]
# # 5. Genrating report for clasification metrics

# %%
def generate_comprehensive_report(results_data, NAME_OF_SIMULATION="simulation"):
    """
    Generuje zbiorczy raport z wynikami dla wszystkich osi,
    pokazujący dokładność, F1, precyzję i czułość na pionowym wykresie.
    Styl dostosowany do publikacji naukowych z polskimi nazwami.
    
    :param results_data: Lista słowników z wynikami
    :param NAME_OF_SIMULATION: Nazwa symulacji do użycia w nazwie pliku
    """
    from collections import Counter
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn.metrics import precision_score, recall_score, f1_score
    
    plt.style.use('default')
    plt.rcParams.update({
        'font.family': 'Arial',     
        'font.size': 12,                  
        'axes.labelsize': 14,
        'axes.titlesize': 16,
        'xtick.labelsize': 12,
        'ytick.labelsize': 12,
        'legend.fontsize': 11,
        'figure.titlesize': 18,
        'axes.linewidth': 1.2,           
        'axes.edgecolor': 'black',
        'axes.facecolor': 'white',
        'figure.facecolor': 'white',
        'axes.grid': False,
        'axes.axisbelow': True,
        'xtick.direction': 'out',         
        'ytick.direction': 'out',
        'xtick.major.size': 6,            
        'ytick.major.size': 6,
        'xtick.minor.size': 3,
        'ytick.minor.size': 3,
        'axes.spines.top': True,
        'axes.spines.right': True,
        'axes.spines.left': True,
        'axes.spines.bottom': True
    })
    
    # Znajdź wszystkie unikalne osie
    axes = sorted(list(set(item['axis_name'] for item in results_data)))
    
    # Przygotuj słownik do zbierania statystyk i metryk
    stats = {axis: {
        'correct': 0, 
        'total': 0, 
        'predictions': Counter(), 
        'true_labels': Counter(),
        'y_true': [],
        'y_pred': []
    } for axis in axes}
    
    # Zlicz poprawne predykcje i przygotuj dane do metryk dla każdej osi
    for item in results_data:
        axis = item['axis_name']
        predicted = item['feature_name']
        
        # WAŻNE: Używamy tego samego filtra co w macierzy pomyłek
        if "balanced" in predicted:
            continue
            
        # Określ typ osi (zgodnie z kodem macierzy)
        axis_type = None
        if 'vaccine_stance' in axis:
            axis_type = 'vaccine_stance'
 
        
        if not axis_type:
            continue

        # Określ wartość rzeczywistą (ground_truth) na podstawie typu osi
        ground_truth_value = None
        if axis_type == 'vaccine_stance':
            ground_truth_value = item.get('ground_truth_vaccine_stance')
   
    
        # Pomiń przypadki z None (jak w macierzy)
        if ground_truth_value is None:
            continue
            
        # Mapowanie zgodne z kodem macierzy pomyłek
        if ground_truth_value is True:
            if axis_type == 'vaccine_stance':
                true_label = f'{axis_type}_opposite'
                binary_true = 1
           
        elif ground_truth_value is False:
            if axis_type == 'vaccine_stance':
                true_label = f'{axis_type}_base'
                binary_true = 0
                
        else:
            continue
        
        # Konwertuj przewidywanie na wartość binarną - POPRAWIONE MAPOWANIE
        # Sprawdź czy przewidywanie pasuje do prawdziwej etykiety
        if predicted == true_label:
            binary_pred = binary_true  # Poprawna predykcja
        else:
            binary_pred = 1 - binary_true  # Niepoprawna predykcja
            
        # Zapisz wartości binarne
        stats[axis]['y_true'].append(binary_true)
        stats[axis]['y_pred'].append(binary_pred)
        
        stats[axis]['predictions'][predicted] += 1
        stats[axis]['true_labels'][true_label] += 1
        stats[axis]['total'] += 1
        if predicted == true_label:
            stats[axis]['correct'] += 1
    
    # Oblicz metryki dla każdej osi - ZGODNIE Z KODEM MACIERZY
    metrics = {}
    for axis in axes:
        if stats[axis]['total'] == 0:
            continue

        # Przygotuj listy dla sklearn (jak w macierzy pomyłek)
        predictions_list = []
        true_labels_list = []
    
        # Zbierz wszystkie predykcje i prawdziwe etykiety
        for i in range(len(stats[axis]['y_true'])):
            # Mapowanie z powrotem na nazwy etykiet
            true_binary = stats[axis]['y_true'][i]
            pred_binary = stats[axis]['y_pred'][i]
            
            # Określ typ osi
            axis_type = None
            if 'vaccine_stance' in axis:
                axis_type = 'vaccine_stance'
        
            if not axis_type:
                continue
 
            # Mapowanie binary -> etykiety (zgodne z macierzą)
            if true_binary == 1:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_opposite'
            else:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_base'
             
            if pred_binary == 1:
                if axis_type == 'vaccine_stance':
                    pred_label = f'{axis_type}_opposite'  
            else:
                if axis_type == 'vaccine_stance':
                    pred_label = f'{axis_type}_base'
     
            
            true_labels_list.append(true_label)
            predictions_list.append(pred_label)
        
        # Oblicz dokładność (najprostszy przypadek)
        accuracy = stats[axis]['correct'] / stats[axis]['total']
        
        # Oblicz metryki sklearn - ZGODNIE Z MACIERZĄ POMYŁEK
        if len(true_labels_list) > 0:
            try:
                # Znajdź wszystkie unikalne klasy
                unique_true = set(true_labels_list)
                unique_pred = set(predictions_list)
                classes = sorted(list(unique_true.union(unique_pred)))
                
                # Użyj weighted average jak w macierzy pomyłek
                precision = precision_score(true_labels_list, predictions_list, 
                                          average='macro', labels=classes, zero_division=0)
                recall = recall_score(true_labels_list, predictions_list, 
                                    average='macro', labels=classes, zero_division=0)
                f1 = f1_score(true_labels_list, predictions_list, 
                            average='macro', labels=classes, zero_division=0)
            except Exception as e:
                print(f"Błąd obliczania metryk dla osi {axis}: {e}")
                precision = 0
                recall = 0
                f1 = 0
        else:
            precision = 0
            recall = 0
            f1 = 0
        
        metrics[axis] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1
        }
    
    # Wybierz osie z dostępnymi metrykami
    valid_axes = [axis for axis in axes if axis in metrics]
    
    if not valid_axes:
        print("\nBrak wystarczających danych dla wszystkich osi.")
        return
    
    # Polskie nazwy metryk
    metric_names = ['Dokładność', 'Precyzja', 'Czułość', 'Wynik F1']
    metric_keys = ['accuracy', 'precision', 'recall', 'f1']
    
    fig, ax = plt.subplots(figsize=(16, 8))
    
    # Parametry słupków
    bar_width = 0.4
    group_spacing = 2.0
    
    # Pozycje grup na osi X
    x_positions = np.arange(len(valid_axes)) * group_spacing
    
    # Wyraziste kolory z dobrym kontrastem
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Niebieski, pomarańczowy, zielony, czerwony
    
    # Wzory dla lepszej rozróżnialności
    patterns = ['', '///', '...', 'xxx']
    
    # Narysuj słupki dla każdej metryki
    bars = []
    for i, (metric_name, metric_key) in enumerate(zip(metric_names, metric_keys)):
        values = [metrics[axis][metric_key] for axis in reversed(valid_axes)]
        
        position = x_positions + (i - 1.5) * bar_width
        bar = ax.bar(position, values, width=bar_width, 
                     color=colors[i], 
                     edgecolor='black', 
                     linewidth=1.0,
                     label=metric_name,
                     alpha=0.8,
                     hatch=patterns[i])
        bars.append(bar)
    
    # Polskie etykiety osi
    ax.set_ylabel('Wartość metryki', fontweight='bold', labelpad=30   ,fontsize=18)
    ax.set_xlabel('Kryteria polaryzacyjne', fontweight='bold', labelpad=30 , fontsize=18)
    
    axis_labels = []

    revered_valid_axes = reversed(valid_axes)
    valid_axes = revered_valid_axes 
    for axis in valid_axes:
        if 'vaccine_stance' in axis:
            axis_labels.append('vaccine_stance')
   
        else:
            # Fallback dla innych nazw
            axis_labels.append(axis.replace('_', ' ').title())

    from matplotlib.ticker import PercentFormatter

    ax.yaxis.set_major_formatter(PercentFormatter(1))


    # Ustaw etykiety osi X
    ax.set_xticks(x_positions)
    ax.set_xticklabels(axis_labels, fontsize=18, ha='center')
    
    # Zakres osi Y z marginesem
    ax.set_ylim(0, 1.01)
    
    # Siatka pozioma dla lepszej czytelności
    ax.grid(axis='y', linestyle='-', alpha=0.4, color='gray', linewidth=0.8)
    ax.set_axisbelow(True)
    
    # Wartości nad słupkami - iteracja od tyłu
    # OPCJA 1: Iteracja od tyłu po grupach słupków (ZALECANA)
    for bar_group in reversed(bars):
        for bar in bar_group:
            height = bar.get_height()
            if height > 0:
                ax.text(bar.get_x() + bar.get_width()/2., height + 0.002,
                        f'{height:.0%}', 
                        ha='center', va='bottom', fontweight='bold', fontsize=16,
                        color='black')

    # OPCJA 1: Legenda po prawej stronie poza wykresem (ZALECANA)
    legend = ax.legend(loc='center left',
                      bbox_to_anchor=(1.02, 0.5),  # (x, y) - x=1.02 oznacza poza prawą krawędzią
                      frameon=True,
                      framealpha=0.95,
                      edgecolor='black',
                      facecolor='white',
                      fontsize=16,
                      title='Metryki',
                      title_fontsize=16)
    legend.get_title().set_fontweight('bold')

    print("\n" + "="*60)
    print("PODSUMOWANIE METRYK KLASYFIKACJI")
    print("="*60)
    for axis in axes:
        print(f"  Dokładność: {metrics[axis]['accuracy']:.4f}")
        print(f"  Precyzja:   {metrics[axis]['precision']:.4f}")
        print(f"  Czułość:    {metrics[axis]['recall']:.4f}")
        print(f"  Wynik F1:   {metrics[axis]['f1']:.4f}")
    print("=" * 60)

    output = ""
    output += "=" * 60 + "\n"
    output += f"{NAME_OF_SIMULATION}\n"
    for axis in axes:
        output += f"\n{axis.upper()}:\n"
        output += f"  Dokładność: {metrics[axis]['accuracy']:.4f}\n"
        output += f"  Precyzja:   {metrics[axis]['precision']:.4f}\n"
        output += f"  Czułość:    {metrics[axis]['recall']:.4f}\n"
        output += f"  Wynik F1:   {metrics[axis]['f1']:.4f}\n"

    output += "=" * 60 + "\n"

    with open(f"./wyniki_klasyfikacji_zdrowotne/{NAME_OF_SIMULATION}_classification_metrics_results.txt", "w", encoding="utf-8") as f:
        f.write(output)


    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_color('black')
        spine.set_linewidth(1.2)
    
    
    plt.tight_layout()
    
    plt.subplots_adjust(right=0.75)  # Zmniejsz szerokość wykresu o 25% dla legendy

    
    plt.savefig(f'./{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}_classification_metrics.png', 
                dpi=300,
                bbox_inches='tight',
                facecolor='white',
                edgecolor='none')
    plt.show()
    

generate_comprehensive_report(results_data=results_metrics, NAME_OF_SIMULATION=NAME_OF_SIMULATION)
# Out:
# ============================================================
# PODSUMOWANIE METRYK KLASYFIKACJI
# ============================================================
#   Dokładność: 0.9016
#   Precyzja:   0.9014
#   Czułość:    0.8970
#   Wynik F1:   0.8989
# ============================================================

# %% [markdown]
# # 6.  Analyze miscassified texts

# %%
def show_misclassified_examples(results_data, axis_name=None, max_examples=5):
    """
    Prosta funkcja pokazująca przykłady błędnych klasyfikacji.
    
    :param results_data: Lista słowników z wynikami
    :param axis_name: Nazwa osi do analizy (None dla wszystkich osi)
    :param max_examples: Maksymalna liczba przykładów do pokazania
    """
    # Funkcja do ładnego formatowania tekstu
    def format_text(text, width=80, indent=6):
        if not text:
            return "[Nie można uzyskać dostępu do tekstu]"
            
        # Podziel tekst na linie o określonej szerokości
        lines = []
        current_line = " " * indent  # Początkowe wcięcie
        
        for word in text.split():
            # Jeśli dodanie słowa przekroczy szerokość, rozpocznij nową linię
            if len(current_line) + len(word) + 1 > width:
                lines.append(current_line)
                current_line = " " * indent + word
            else:
                if current_line == " " * indent:  # Jeśli linia jest pusta (oprócz wcięcia)
                    current_line += word
                else:
                    current_line += " " + word
        
        # Dodaj ostatnią linię
        if current_line != " " * indent:
            lines.append(current_line)
            
        return str("\n".join(lines))
    
    # Przygotuj osie do analizy
    if axis_name:
        axes_to_analyze = [axis_name]
    else:
        axes_to_analyze = sorted(list(set(item['axis_name'] for item in results_data)))
    


    output = ""

    # Analizuj każdą oś
    for current_axis in axes_to_analyze:
        output += f"\n{'='*50}"
        output +=f"BŁĘDNE KLASYFIKACJE DLA OSI: {current_axis}"
        output +=f"{'='*50}"
        
        # Filtruj wyniki dla bieżącej osi
        axis_results = [item for item in results_data if item['axis_name'] == current_axis]
        
        if not axis_results:
            print(f"Brak danych dla osi {current_axis}")
            continue
        
        # Określ typ osi
        axis_type = None
        if 'vaccine_stance' in current_axis:
            axis_type = 'vaccine_stance'
            true_field = 'ground_truth_vaccine_stance'
        else:
            print(f"Nieobsługiwany typ osi: {current_axis}")
            continue
        
        # Analizuj każdy wynik
        misclassified = []
        total = 0
        correct = 0
        
        for item in axis_results:
            predicted = item['feature_name']
            ground_truth = item.get(true_field)
            
            # Pomiń przypadki balanced
            if ground_truth is None:
                continue
                
            total += 1
            
            # Określ prawdziwą etykietę
            true_label = None
            if ground_truth is True:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_opposite'
                
            elif ground_truth is False:
                if axis_type == 'vaccine_stance':
                    true_label = f'{axis_type}_base'

            
            # Sprawdź, czy klasyfikacja jest poprawna
            if predicted == true_label:
                correct += 1
            else:
                # To jest błędna klasyfikacja
                misclassified.append({
                    'item': item,
                    'true_label': true_label,
                    'predicted': predicted
                })
        

        # Wyświetl podsumowanie
        accuracy = correct / total if total > 0 else 0
        output += f"\nŁącznie próbek: {total}"
        output +=f"Poprawnych klasyfikacji: {correct} ({accuracy:.2%})" 
        output +=f"Błędnych klasyfikacji: {len(misclassified)} ({1-accuracy:.2%})"

        output += "Błędne klasyfikacje:\n"


        for i, entry in enumerate(misclassified):
            item = entry['item']
            true_label = entry['true_label']
            predicted = entry['predicted']

            # Skrócone nazwy
            true_short = true_label.split('_')[-1]
            pred_short = predicted.split('_')[-1]

            # Pobranie tekstu
            text = ""
            if 'page' in item and hasattr(item['page'], 'page_content'):
                text = item['page'].page_content

            # Dodaj do outputu
            output += f"\n{i+1}. POWINNO BYĆ {true_short} a jest ZAKWALIFIKOWANY  jako {pred_short}\n"
            output += format_text(text) + "\n"

    # Zapis do pliku (oddzielnie dla każdej osi)
    filename = f"{NAME_OF_SIMULATION}/{NAME_OF_SIMULATION}_misclassified_texts.txt"
    with open(filename, "w", encoding="utf-8") as file:
        file.write(output)


# Przykład użycia:
show_misclassified_examples(results_data=results_metrics)
